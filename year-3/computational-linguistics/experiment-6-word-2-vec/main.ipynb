# %% [markdown]
# # Experiment 6 - Word2Vec Implementation

# %%
import pandas as pd

# %% [markdown]
# Setting the hyper parameters for the Word2Vec model

# %%
processedTweetsDataFrame = pd.read_csv(r'../assets/data/processed-tweets.csv')
processedTweetsDataFrame
# Out:
#     Unnamed: 0            0            1          2               3  \
# 0            0        heart        everi     famili          fortun
# 1            1  groundbreak      filmmak       well             dad
# 2            2           rt  markruffalo      parab               n
# 3            3     excelent       debora       dpio          melhor
# 4            4           eu          com        voc       rdjbrazil
# ..         ...          ...          ...        ...             ...
# 95          95           rt           fp     coalit             co2
# 96          96         crew         bose     downey               x
# 97          97           rt           fp     coalit  robertdowneyjr
# 98          98         good       friend  valentino         vettori
# 99          99           rt           fp     coalit          explor
#
#              4        5            6             7          8  ...        31  \
# ...

# %%
hyperParameters = {
    # Context window +- center word
	'window_size': 2,
	# Dimensions of word embeddings, i.e., size of hidden layer
	'n': 10,
	# Number of training epochs
	'epochs': 50,
	# Learning rate
	'learning_rate': 0.01
}

# %% [markdown]
# Generating training data for the model

# %%
# Initialise object
w2v = word2vec()
# Numpy ndarray with one-hot representation for [target_word, context_words]
training_data = w2v.generate_training_data(settings, corpus)

# %% [markdown]
# ---
# # Resources
# 1. [Article on word embedding](https://stackabuse.com/implementing-word2vec-with-gensim-library-in-python/)
