# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import re

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

from gensim.models import Word2Vec

stopWords = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ## Read tweets

# %%
df = pd.read_csv(r'../assets/data/tweets.csv')

tweets = df['text']

tweets
# Out:
# 0              RIP #TomVerlaine https://t.co/w40iGeqmKK
# 1     Reposted from @vintage.cheese #shesjustdrawnth...
# 2     Reposted from @thehorrorgallery 😂🤣 🔥 \n\nFollo...
# 3     Reposted from @jess_rene_ #art #witch #witchcr...
# 4     Reposted from @bjanetrose 🥀 @kostle_laugh_with...
#                             ...
# 95    Reposted from @thelegendsofmusic The White Str...
# 96    Reposted from @paulrosolie  In the last two we...
# 97    Reposted from @bjanetrose 🥀 #wonderwoman 🥀  ii...
# 98    Reposted from dropkickblues Chuck Berry, what ...
# 99    Hell of a crowd in Wellington, NZ tonight, you...
# Name: text, Length: 100, dtype: object

# %% [markdown]
# ## Pre-process tweets

# %%
tweetList = []
tweetSentences = []

for i, tweet in enumerate(tweets):
    # Convert the tweet to lowercase using REGEX
    for f in re.findall("([A-Z]+)", tweet):
        tweet = tweet.replace(f, f.lower())

    # Removing special characters and replacing them with a space
    tweet = re.sub("[^A-Za-z0-9]", " ", tweet, 0, re.IGNORECASE)
    
    # From a single sentence, store all the words 
    wordsInTweet = nltk.word_tokenize(tweet)
    
    # Filter out all the stop words
    wordsInTweet = [word for word in wordsInTweet if word not in stopWords]
    
    # Stem each of the tweets
    wordsInTweet = [stemmer.stem(word) for word in wordsInTweet if word not in stopWords]
    
    # Lemmatize each of the tweets
    wordsInTweet = [lemmatizer.lemmatize(word) for word in wordsInTweet]
    
    # Append them to a list
    tweetList.append(wordsInTweet)
    
    # Remake the sentences after removing the stop words
    tweetSentences.append(' '.join(wordsInTweet))

# %%
tweetList
# Out:
# [['rip', 'tomverlain', 'http', 'co', 'w40igeqmkk'],
#  ['repost',
#   'vintag',
#   'chees',
#   'shesjustdrawnthatway',
#   'terrygilliam',
#   'montypython',
#   'legend',
#   '1960',
#   '1970',
#   'vintagechees',
#   'iiii',
#   'http',
#   'co',
#   '2hpfzj1jvm'],
#  ['repost',
#   'thehorrorgalleri',
#   'follow',
#   'u',
#   'thehorrorgalleri',
#   'peligrosovalley',
#   'iiii',
#   'http',
#   'co',
#   'xkpm5ruwp3'],
#  ['repost',
#   'jess',
#   'rene',
#   'art',
#   'witch',
#   'witchcraft',
#   'instaart',
#   'macabr',
#   'macabreart',
#   'artist',
#   'darkart',
#   'dark',
#   'instagood',
#   'salem',
#   'joseph',
#   'tomanek',
#   'philip',
#   'hofmann',
#   'iiii',
#   'http',
#   'co',
#   'wvuuumxzll'],
#  ['repost',
#   'bjanetros',
#   'kostl',
#   'laugh',
#   'dead',
#   'iiii',
#   'http',
#   'co',
#   'cgv2hmyl1i'],
#  ['post', 'photo', 'http', 'co', 'vjjloc4scg'],
#  ['post', 'photo', 'http', 'co', '2y6cfktrvw'],
#  ['post', 'photo', 'http', 'co', 'a8nkjpfqho'],
#  ['repost',
#   'bizarredoctor',
#   'season',
#   'witch',
#   'sound',
#   'artist',
#   'minelauvart',
#   'iiii',
#   'http',
#   'co',
#   'jspww6de3k'],
#  ['happi', 'birthday', 'steveadl', 'iiii', 'http', 'co', 'q2hjtdrmsa'],
#  ['repost',
#   'patfromstoke1',
#   'repost',
#   'fakedream',
#   'ai',
#   'iiii',
#   'http',
#   'co',
#   'spfo4fhakc'],
#  ['repost',
#   'bjanetros',
#   'artist',
#   'trinitycatdelin',
#   'iiii',
#   'http',
#   'co',
#   '9lgrwvg1nj'],
#  ['repost',
#   'jayprehistoricpet',
#   'one',
#   'absolut',
#   'giant',
#   'komodo',
#   'dragon',
#   'seem',
#   'like',
#   'live',
#   'dinosaur',
#   'run',
#   'laura',
#   'iiii',
#   'http',
#   'co',
#   'qc9jsxubif'],
#  ['repost',
#   'thelegendsofmus',
#   'carl',
#   'perkin',
#   'play',
#   'honey',
#   'live',
#   '1956',
#   'music',
#   'rocknrol',
#   'carlperkin',
#   'iiii',
#   'http',
#   'co',
#   '3r6xlhprov'],
#  ['http', 'co', 'azjzxpfqsi', 'iiii'],
#  ['repost', 'worldofdisnep', 'imadeej', 'iiii', 'http', 'co', '5couafjtl6'],
#  ['rip', 'davidcrosbi', 'http', 'co', 'vblwdqdcj0'],
#  ['art', 'xoticartwork', 'iiii', 'http', 'co', 'hstneis1qm'],
#  ['repost',
#   'thelegendsofmus',
#   'stone',
#   'templ',
#   'pilot',
#   'play',
#   'crackerman',
#   'live',
#   'music',
#   'rocknrol',
#   'stonetemplepilot',
#   'scottweiland',
#   'deandeleo',
#   'robertdeleo',
#   'ericketz',
#   'iiii',
#   'http',
#   'co',
#   'bizzg3udv3'],
#  ['happi', 'birthday', 'micktaylor', 'iiii', 'http', 'co', 'jstmsi2t2z'],
#  ['avail',
#   'new',
#   'collect',
#   'slash',
#   'standard',
#   'edit',
#   'offer',
#   'wide',
#   'access',
#   'version',
#   'book',
#   'featur',
#   '364',
#   'page',
#   'hardcov',
#   '240',
#   'x',
#   '340',
#   'mm',
#   '9',
#   '45',
#   'x',
#   '13',
#   '39',
#   'slashnew',
#   'http',
#   'co',
#   'pgrlnjuedi'],
#  ['repost',
#   'crave',
#   'wild',
#   'knock',
#   'knock',
#   'jukinmedia',
#   'via',
#   'bestialnatur',
#   'pay',
#   'tf',
#   'clock',
#   'im',
#   'comin',
#   'collect',
#   'iiii',
#   'http',
#   'co',
#   'mg4vwhbtpt'],
#  ['repost',
#   'thewhiskyagogo',
#   '59',
#   'year',
#   'ago',
#   'whiski',
#   'born',
#   'happi',
#   'birthday',
#   'whiski',
#   'go',
#   'go',
#   'thewhiskyagogo',
#   'happybirthday',
#   'thewhiskyis59',
#   'happybirthdaywhiski',
#   'whiskyjanuary16th',
#   'whiskyjanuary16th1964',
#   'iiii',
#   'http',
#   'co',
#   'ibqoe31kxt'],
#  ['happi',
#   '8th',
#   'anniversari',
#   'worlovesmrslash',
#   'offici',
#   'fan',
#   'page',
#   'support',
#   'smkc',
#   'thank',
#   'dedic',
#   'commit',
#   'time',
#   'cheer',
#   'iiii'],
#  ['post', 'photo', 'http', 'co', '7rfq4zn1h1'],
#  ['repost',
#   'lordrarerock',
#   'oh',
#   'sing',
#   'joni',
#   'mitchel',
#   'mesmer',
#   'one',
#   'largest',
#   'gather',
#   'human',
#   'histori',
#   'california',
#   'isl',
#   'wight',
#   'festiv',
#   '1970',
#   'iiii',
#   'http',
#   'co',
#   'ytxbwlaujz'],
#  ['happi', 'birthday', 'zakwyld', 'iiii', 'http', 'co', 'j6xyz7itxk'],
#  ['repost', 'jess', 'rene', 'iiii', 'http', 'co', 'mzfxle6hz'],
#  ['happi', 'birthday', 'davegrohl', 'iiii', 'http', 'co', 'nyc26dnb6c'],
#  ['sad', 'news', 'rip', 'robbieknievel', 'http', 'co', 'auiwmkknht'],
#  ['repost',
#   'factpil',
#   'creepi',
#   'creepyashel',
#   'creepyasfuck',
#   'creepypopcorn',
#   'popcornfac',
#   'skull',
#   'iiii',
#   'http',
#   'co',
#   '5uyxkg9zlr'],
#  ['repost',
#   'wildattract',
#   'mejdinho',
#   'emerald',
#   'tree',
#   'boa',
#   'iiii',
#   'http',
#   'co',
#   'vlczhptdqg'],
#  ['repost',
#   'mrwupass',
#   'repost',
#   'liveguitarsolo',
#   'rip',
#   'jeff',
#   'beck',
#   'perfect',
#   'exampl',
#   'geniu',
#   'thank',
#   'jb',
#   'http',
#   'co',
#   'wjqhyhsdw'],
#  ['post', 'photo', 'http', 'co', 'llsyrsevho'],
#  ['repost', 'zugart', 'iiii', 'http', 'co', 'e8jj3hufaf'],
#  ['repost',
#   'thelegendsofmusictv',
#   'queen',
#   'stone',
#   'age',
#   'play',
#   'sat',
#   'ocean',
#   'live',
#   'david',
#   'letterman',
#   'show',
#   'music',
#   'rocknrol',
#   'queensofthestoneag',
#   'davegrohl',
#   'joshhomm',
#   'troyvanleeuwen',
#   'deanfertita',
#   'michaelshuman',
#   'joecastillo',
#   'iiii',
#   'http',
#   'co',
#   'b29tajdklu'],
#  ['happi',
#   'birthday',
#   'rodstewart',
#   'photo',
#   'rosshalfin',
#   'iiii',
#   'http',
#   'co',
#   '7eu0wcdabu'],
#  ['repost', '52graham52', 'iiii', 'http', 'co', 'oro7adrnth'],
#  ['happi', 'birthday', 'davidjohansen', 'iiii', 'http', 'co', 'fyhl2tjfnb'],
#  ['happi',
#   'birthday',
#   'jimmypag',
#   'photo',
#   'rosshalfin',
#   'iiii',
#   'http',
#   'co',
#   'xendyoy2wu'],
#  ['shop',
#   'onlin',
#   'get',
#   '30',
#   'storewid',
#   'part',
#   'slash',
#   'winter',
#   'sale',
#   'slashnew',
#   'http',
#   'co',
#   '5dbmof8zlz'],
#  ['repost', 'guitarsdaili', 'iiii', 'http', 'co', '3dvgh72osm'],
#  ['check',
#   'friend',
#   'corinhardi',
#   'killer',
#   'seri',
#   'gangsoflondon',
#   'amcplu',
#   'noth',
#   'short',
#   'bad',
#   'as',
#   'corinhardi',
#   'amcplu',
#   'gangsoflondon',
#   'iiii',
#   'http',
#   'co',
#   'b3afhca3zk'],
#  ['post', 'photo', 'http', 'co', 'w6xw8bhmk3'],
#  ['iiii', 'http', 'co', '5e9bzatmyl'],
#  ['repost',
#   'thelegendsofmus',
#   'iggi',
#   'pop',
#   'play',
#   'lust',
#   'life',
#   'live',
#   'manchest',
#   '1977',
#   'music',
#   'rocknrol',
#   'iggypop',
#   'davidbowi',
#   'iiii',
#   'http',
#   'co',
#   '6qwazssnj6'],
#  ['1928', 'photograph', 'unknown', 'iiii', 'http', 'co', 'abbdk8ndy'],
#  ['happi',
#   '10',
#   'year',
#   'anniversari',
#   'fansofslashw',
#   '10',
#   'year',
#   'repres',
#   'smkc',
#   'thank',
#   'ongo',
#   'support',
#   'time',
#   '10',
#   'cheer',
#   'iiii'],
#  ['repost',
#   'darkmatterincorp',
#   'altern',
#   'end',
#   'get',
#   'shirt',
#   'sticker',
#   'http',
#   'co',
#   'qpzdtutjiq',
#   'dm',
#   'commiss',
#   'iiii',
#   'http',
#   'co',
#   'zn7sc2b4tw'],
#  ['repost',
#   'mirror',
#   'nuderobot',
#   'nuderobot',
#   'yassin',
#   'cavali',
#   'iiii',
#   'http',
#   'co',
#   'yuiznhigxb'],
#  ['repost',
#   'thelegendsofmus',
#   'pretend',
#   'play',
#   'tattoo',
#   'love',
#   'boy',
#   'live',
#   '1980',
#   'music',
#   'rocknrol',
#   'pretend',
#   'chrissiehynd',
#   'martinchamb',
#   'petefarndon',
#   'jameshoneymanscott',
#   'iiii',
#   'http',
#   'co',
#   'hv9gybr80b'],
#  ['repost',
#   'bencordova',
#   'guitar',
#   'face',
#   'rodstewartandthefac',
#   'paulmccartney',
#   'iiii',
#   'http',
#   'co',
#   'cpg6c2tufv'],
#  ['repost', 'toxictoon', 'great', 'week', 'iiii', 'http', 'co', 'ylv0l3mekb'],
#  ['repost',
#   'thelegendsofmus',
#   'promot',
#   'footag',
#   'sid',
#   'viciou',
#   'perform',
#   'sex',
#   'pistol',
#   'cover',
#   'frank',
#   'sinatra',
#   'way',
#   'music',
#   'punkrock',
#   'sexpistol',
#   'sidvici',
#   'glenmatlock',
#   'johnlydon',
#   'paulcook',
#   'stevejon',
#   'iiii',
#   'http',
#   'co',
#   'ytwndbxmxt'],
#  ['happi', 'new', 'year', 'iiii', 'http', 'co', 'h2bcmzkzgu'],
#  ['happi', 'birthday', 'tomhamilton', 'iiii', 'http', 'co', '6qyw2ffd8w'],
#  ['rt',
#   'marta',
#   'zawadzka',
#   'help',
#   'environ',
#   'plant',
#   'tree',
#   'creat',
#   'xrayt',
#   'zone',
#   'nft',
#   'collabor',
#   'sla',
#   'amp',
#   'marta',
#   'zawadz'],
#  ['repost',
#   'anti',
#   'cgi',
#   'war',
#   'gargantua',
#   '1966',
#   'iiii',
#   'http',
#   'co',
#   'iqy40nlmb5'],
#  ['repost',
#   'fmx',
#   'motocrosss',
#   'robbiemaddison',
#   'iiii',
#   'http',
#   'co',
#   'lj0ahj8u0c'],
#  ['post', 'photo', 'http', 'co', 'yydeerl6tv'],
#  ['repost',
#   'lordrarerock',
#   'whatev',
#   'girl',
#   'put',
#   'spell',
#   'jimi',
#   'hendrix',
#   'perform',
#   'purpl',
#   'haze',
#   'atlanta',
#   'pop',
#   'festiv',
#   '1970',
#   'iiii',
#   'http',
#   'co',
#   '7bt6ukau38'],
#  ['happi',
#   '10th',
#   'anniversari',
#   'slashbolivia',
#   'support',
#   'smkc',
#   'massiv',
#   'thank',
#   'continu',
#   'represent',
#   'let',
#   'go',
#   'anoth',
#   '10',
#   'year',
#   'cheer',
#   'iiii'],
#  ['repost',
#   'eratk666',
#   'wonkafac',
#   'darkmatterincorp',
#   'iiii',
#   'http',
#   'co',
#   'dae7n0au5p'],
#  ['repost',
#   'thelegendsofmus',
#   'motorhead',
#   'play',
#   'damag',
#   'case',
#   'live',
#   '2002',
#   'music',
#   'rocknrol',
#   'lemmykilmist',
#   'philcampbel',
#   'mikkeyde',
#   'iiii',
#   'http',
#   'co',
#   'yqtufgrwot'],
#  ['repost', 'blue', 'tshirt', 'iiii', 'http', 'co', 'qefkb3h54'],
#  ['happi', 'birthday', 'larsulrich', 'iiii', 'http', 'co', '2f8rrhhooe'],
#  ['repost',
#   'creep',
#   'sock',
#   'twilight',
#   'zone',
#   'night',
#   'meek',
#   '1959',
#   'anoth',
#   'christma',
#   'speical',
#   'recommend',
#   'iiii',
#   'http',
#   'co',
#   'rlmvtyg8k9'],
#  ['merri',
#   'christma',
#   'repost',
#   'patfromstoke1',
#   'repost',
#   'motorhead',
#   'fanlove01',
#   'mot',
#   'rhead',
#   'lemmi',
#   'iiii',
#   'http',
#   'co',
#   'rnsbhetuaf'],
#  ['repost',
#   'thelegendsofmus',
#   'kiss',
#   'play',
#   'god',
#   'thunder',
#   'live',
#   'tokyo',
#   '1977',
#   'music',
#   'rocknrol',
#   'kiss',
#   'genesimmon',
#   'paulstanley',
#   'petercriss',
#   'iiii',
#   'http',
#   'co',
#   'wdhkqwq391'],
#  ['check',
#   'fantast',
#   'photo',
#   'expo',
#   'eddievanhalen',
#   'icon',
#   'rock',
#   'photograph',
#   'neilzlowzow',
#   'best',
#   'photo',
#   'histori',
#   'evh',
#   'unbeliev',
#   'qualiti',
#   'iiii',
#   'http',
#   'co',
#   'ye884kcvzt'],
#  ['repost',
#   'rorygallagheroffici',
#   'rori',
#   'play',
#   'learnt',
#   'lesson',
#   'german',
#   'tv',
#   'show',
#   'beat',
#   'club',
#   'day',
#   '1971',
#   'iiii',
#   'http',
#   'co',
#   'mwfyohhsbx'],
#  ['repost',
#   'lordrarerock',
#   'rememb',
#   'someon',
#   'realli',
#   'love',
#   'highwayman',
#   'play',
#   'live',
#   'forev',
#   'live',
#   'studio',
#   '1995',
#   'highwayman',
#   'featur',
#   'countri',
#   'legend',
#   'johnni',
#   'cash',
#   'waylon',
#   'jen',
#   'kri',
#   'kristofferson',
#   'willi',
#   'nelson',
#   'iiii',
#   'http',
#   'co',
#   'ax4dh8gzlg'],
#  ['repost', 'thehorrorgalleri', 'iiii', 'http', 'co', '1chruuvldp'],
#  ['post', 'photo', 'http', 'co', 'e6ki6itil6'],
#  ['post', 'photo', 'http', 'co', 'cyoz0zypmu'],
#  ['repost', '52graham52', 'iiii', 'http', 'co', 'yyckcs4zob'],
#  ['today',
#   'slash2world',
#   'celebr',
#   '10th',
#   'anniversari',
#   'offici',
#   'fan',
#   'page',
#   'smkc',
#   'thank',
#   'support',
#   'cheer',
#   'iiii'],
#  ['repost',
#   'dropkickblu',
#   'jame',
#   'brown',
#   'time',
#   'live',
#   'david',
#   'letterman',
#   '1982',
#   'perform',
#   'call',
#   'best',
#   'live',
#   'perform',
#   'televis',
#   'histori',
#   'iiii',
#   'http',
#   'co',
#   'cbem70zfr'],
#  ['happi', 'birthday', 'keithrichard', 'iiii', 'http', 'co', 'qmh0qxgyg1'],
#  ['repost',
#   'lisarosa',
#   'statu',
#   'liberti',
#   'construct',
#   '1885',
#   'iiii',
#   'http',
#   'co',
#   '0dtnagzy3m'],
#  ['repost',
#   'bizarredoctor',
#   'muppet',
#   'mania',
#   '10',
#   'bizarr',
#   'wild',
#   'snap',
#   'artist',
#   'sentientmuppetfactori',
#   'beth',
#   'frey',
#   'iiii',
#   'http',
#   'co',
#   '6el3kdtrnj'],
#  ['repost',
#   'thelegendsofmus',
#   'aerosmith',
#   'play',
#   'livin',
#   'edg',
#   'live',
#   '1994',
#   'music',
#   'rocknrol',
#   'aerosmith',
#   'bradwhitford',
#   'joeperri',
#   'tomhamilton',
#   'joeykram',
#   'steventyl',
#   'iiii',
#   'http',
#   'co',
#   'gtlrbeyglr'],
#  ['happi', 'birthday', 'billyfgibbon', 'iiii', 'http', 'co', 'shszc51gh6'],
#  ['repost',
#   'eratk666',
#   'creaturet',
#   'sauci',
#   'lagoon',
#   'mark',
#   'alfrey',
#   'laguna',
#   'markalfrey',
#   'mark',
#   'alfrey',
#   'art',
#   'iiii',
#   'http',
#   'co',
#   '9iujj4sg2f'],
#  ['repost',
#   'bjanetros',
#   'artist',
#   'arthur',
#   'berzinsh',
#   'iiii',
#   'http',
#   'co',
#   'vp3ikayjar'],
#  ['repost',
#   'lordrarerock',
#   'seem',
#   'jame',
#   'gang',
#   'perform',
#   'walk',
#   'away',
#   '1971',
#   'beat',
#   'club',
#   'iiii',
#   'http',
#   'co',
#   'fmz8vqfqoy'],
#  ['repost',
#   'mothpet',
#   'ai',
#   'art',
#   'anim',
#   'mothpet',
#   'softwar',
#   'werbleapp',
#   'iiii',
#   'http',
#   'co',
#   'wqecujaqfr'],
#  ['repost',
#   'infern',
#   'art',
#   'witch',
#   'sirin',
#   'waldemar',
#   'von',
#   'kozak',
#   'twilight',
#   'time',
#   'witch',
#   'hour',
#   'prais',
#   'might',
#   'time',
#   'devil',
#   'blood',
#   'iiii',
#   'http',
#   'co',
#   'cis7fc7rqo'],
#  ['happi', 'birthday', 'nikkisixx', 'iiii', 'http', 'co', 'wz6yklltfp'],
#  ['happi',
#   'birthday',
#   'creativ',
#   'mastermind',
#   'brother',
#   'ashhudson',
#   'ashflix',
#   'n',
#   'chill',
#   'iiii',
#   'http',
#   'co',
#   'ekonrnnwdp'],
#  ['repost',
#   'bencordova',
#   'guitar',
#   'woodi',
#   'ronwood',
#   'ronniewood',
#   'face',
#   'ohlala',
#   'thefac',
#   'ronnielan',
#   'britrock',
#   'uk',
#   'iiii',
#   'http',
#   'co',
#   'wn4mlqnsfn'],
#  ['repost',
#   'jess',
#   'rene',
#   'art',
#   'bartheijlen',
#   'death',
#   'instaart',
#   'skull',
#   'skeleton',
#   'darkart',
#   'dark',
#   'macabr',
#   'mood',
#   'instagood',
#   'horror',
#   'gore',
#   'evil',
#   'macabreart',
#   'weekendvib',
#   'iiii',
#   'http',
#   'co',
#   '8yvjexga1c'],
#  ['repost', 'worldofdisnep', 'dangrlab', 'iiii', 'http', 'co', 'agvxfxvpyo'],
#  ['thank',
#   'auckland',
#   'nz',
#   'fit',
#   'end',
#   'tour',
#   'southern',
#   'hemispher',
#   'guy',
#   'amaz',
#   'rain',
#   'amp',
#   'one',
#   'book',
#   'rnfnr',
#   'cheer',
#   'iiii'],
#  ['help',
#   'environ',
#   'plant',
#   'tree',
#   'creat',
#   'xrayt',
#   'zone',
#   'nft',
#   'collabor',
#   'slash',
#   'marta',
#   'zawadzka',
#   'support',
#   'onetreepl',
#   'limit',
#   'collect',
#   '6',
#   'nft',
#   'drop',
#   'announc',
#   'join',
#   'xrayt',
#   'zone',
#   'discord',
#   'http',
#   'co',
#   'zaqp6eehbx',
#   'http',
#   'co',
#   '4b69xytzku'],
#  ['repost',
#   'thelegendsofmus',
#   'white',
#   'stripe',
#   'play',
#   'hardest',
#   'button',
#   'button',
#   'live',
#   'read',
#   'festiv',
#   '2004',
#   'music',
#   'rocknrol',
#   'thewhitestrip',
#   'jackwhit',
#   'megwhit',
#   'iiii',
#   'http',
#   'co',
#   'uiscuuziko'],
#  ['repost',
#   'paulrosoli',
#   'last',
#   'two',
#   'week',
#   'rais',
#   'enough',
#   'money',
#   'protect',
#   '1000',
#   'acr',
#   'rainforest',
#   'thank',
#   'everyon',
#   'boost',
#   'share',
#   'especi',
#   'thank',
#   'everyon',
#   'donat',
#   'junglekeep',
#   'iiii',
#   'http',
#   'co',
#   'kvwkdvsbfv'],
#  ['repost', 'bjanetros', 'wonderwoman', 'iiii', 'http', 'co', 'powij5ohoi'],
#  ['repost',
#   'dropkickblu',
#   'chuck',
#   'berri',
#   'legend',
#   'iiii',
#   'http',
#   'co',
#   'hlkbpkwllv'],
#  ['hell',
#   'crowd',
#   'wellington',
#   'nz',
#   'tonight',
#   'guy',
#   'kick',
#   'as',
#   'thank',
#   'like',
#   'add',
#   '4',
#   'wonder',
#   'day',
#   'wellington',
#   'thank',
#   'super',
#   'cool',
#   'peopl',
#   'pleasur',
#   'interact',
#   'genuin',
#   'hospit',
#   'cheer',
#   'iiii']]

# %%
type(tweetSentences)
# Out:
# list

# %%
tweetSentences
# Out:
# ['rip tomverlain http co w40igeqmkk',
#  'repost vintag chees shesjustdrawnthatway terrygilliam montypython legend 1960 1970 vintagechees iiii http co 2hpfzj1jvm',
#  'repost thehorrorgalleri follow u thehorrorgalleri peligrosovalley iiii http co xkpm5ruwp3',
#  'repost jess rene art witch witchcraft instaart macabr macabreart artist darkart dark instagood salem joseph tomanek philip hofmann iiii http co wvuuumxzll',
#  'repost bjanetros kostl laugh dead iiii http co cgv2hmyl1i',
#  'post photo http co vjjloc4scg',
#  'post photo http co 2y6cfktrvw',
#  'post photo http co a8nkjpfqho',
#  'repost bizarredoctor season witch sound artist minelauvart iiii http co jspww6de3k',
#  'happi birthday steveadl iiii http co q2hjtdrmsa',
#  'repost patfromstoke1 repost fakedream ai iiii http co spfo4fhakc',
#  'repost bjanetros artist trinitycatdelin iiii http co 9lgrwvg1nj',
#  'repost jayprehistoricpet one absolut giant komodo dragon seem like live dinosaur run laura iiii http co qc9jsxubif',
#  'repost thelegendsofmus carl perkin play honey live 1956 music rocknrol carlperkin iiii http co 3r6xlhprov',
#  'http co azjzxpfqsi iiii',
#  'repost worldofdisnep imadeej iiii http co 5couafjtl6',
#  'rip davidcrosbi http co vblwdqdcj0',
#  'art xoticartwork iiii http co hstneis1qm',
#  'repost thelegendsofmus stone templ pilot play crackerman live music rocknrol stonetemplepilot scottweiland deandeleo robertdeleo ericketz iiii http co bizzg3udv3',
#  'happi birthday micktaylor iiii http co jstmsi2t2z',
#  'avail new collect slash standard edit offer wide access version book featur 364 page hardcov 240 x 340 mm 9 45 x 13 39 slashnew http co pgrlnjuedi',
#  'repost crave wild knock knock jukinmedia via bestialnatur pay tf clock im comin collect iiii http co mg4vwhbtpt',
#  'repost thewhiskyagogo 59 year ago whiski born happi birthday whiski go go thewhiskyagogo happybirthday thewhiskyis59 happybirthdaywhiski whiskyjanuary16th whiskyjanuary16th1964 iiii http co ibqoe31kxt',
#  'happi 8th anniversari worlovesmrslash offici fan page support smkc thank dedic commit time cheer iiii',
#  'post photo http co 7rfq4zn1h1',
#  'repost lordrarerock oh sing joni mitchel mesmer one largest gather human histori california isl wight festiv 1970 iiii http co ytxbwlaujz',
#  'happi birthday zakwyld iiii http co j6xyz7itxk',
#  'repost jess rene iiii http co mzfxle6hz',
#  'happi birthday davegrohl iiii http co nyc26dnb6c',
#  'sad news rip robbieknievel http co auiwmkknht',
#  'repost factpil creepi creepyashel creepyasfuck creepypopcorn popcornfac skull iiii http co 5uyxkg9zlr',
#  'repost wildattract mejdinho emerald tree boa iiii http co vlczhptdqg',
#  'repost mrwupass repost liveguitarsolo rip jeff beck perfect exampl geniu thank jb http co wjqhyhsdw',
#  'post photo http co llsyrsevho',
#  'repost zugart iiii http co e8jj3hufaf',
#  'repost thelegendsofmusictv queen stone age play sat ocean live david letterman show music rocknrol queensofthestoneag davegrohl joshhomm troyvanleeuwen deanfertita michaelshuman joecastillo iiii http co b29tajdklu',
#  'happi birthday rodstewart photo rosshalfin iiii http co 7eu0wcdabu',
#  'repost 52graham52 iiii http co oro7adrnth',
#  'happi birthday davidjohansen iiii http co fyhl2tjfnb',
#  'happi birthday jimmypag photo rosshalfin iiii http co xendyoy2wu',
#  'shop onlin get 30 storewid part slash winter sale slashnew http co 5dbmof8zlz',
#  'repost guitarsdaili iiii http co 3dvgh72osm',
#  'check friend corinhardi killer seri gangsoflondon amcplu noth short bad as corinhardi amcplu gangsoflondon iiii http co b3afhca3zk',
#  'post photo http co w6xw8bhmk3',
#  'iiii http co 5e9bzatmyl',
#  'repost thelegendsofmus iggi pop play lust life live manchest 1977 music rocknrol iggypop davidbowi iiii http co 6qwazssnj6',
#  '1928 photograph unknown iiii http co abbdk8ndy',
#  'happi 10 year anniversari fansofslashw 10 year repres smkc thank ongo support time 10 cheer iiii',
#  'repost darkmatterincorp altern end get shirt sticker http co qpzdtutjiq dm commiss iiii http co zn7sc2b4tw',
#  'repost mirror nuderobot nuderobot yassin cavali iiii http co yuiznhigxb',
#  'repost thelegendsofmus pretend play tattoo love boy live 1980 music rocknrol pretend chrissiehynd martinchamb petefarndon jameshoneymanscott iiii http co hv9gybr80b',
#  'repost bencordova guitar face rodstewartandthefac paulmccartney iiii http co cpg6c2tufv',
#  'repost toxictoon great week iiii http co ylv0l3mekb',
#  'repost thelegendsofmus promot footag sid viciou perform sex pistol cover frank sinatra way music punkrock sexpistol sidvici glenmatlock johnlydon paulcook stevejon iiii http co ytwndbxmxt',
#  'happi new year iiii http co h2bcmzkzgu',
#  'happi birthday tomhamilton iiii http co 6qyw2ffd8w',
#  'rt marta zawadzka help environ plant tree creat xrayt zone nft collabor sla amp marta zawadz',
#  'repost anti cgi war gargantua 1966 iiii http co iqy40nlmb5',
#  'repost fmx motocrosss robbiemaddison iiii http co lj0ahj8u0c',
#  'post photo http co yydeerl6tv',
#  'repost lordrarerock whatev girl put spell jimi hendrix perform purpl haze atlanta pop festiv 1970 iiii http co 7bt6ukau38',
#  'happi 10th anniversari slashbolivia support smkc massiv thank continu represent let go anoth 10 year cheer iiii',
#  'repost eratk666 wonkafac darkmatterincorp iiii http co dae7n0au5p',
#  'repost thelegendsofmus motorhead play damag case live 2002 music rocknrol lemmykilmist philcampbel mikkeyde iiii http co yqtufgrwot',
#  'repost blue tshirt iiii http co qefkb3h54',
#  'happi birthday larsulrich iiii http co 2f8rrhhooe',
#  'repost creep sock twilight zone night meek 1959 anoth christma speical recommend iiii http co rlmvtyg8k9',
#  'merri christma repost patfromstoke1 repost motorhead fanlove01 mot rhead lemmi iiii http co rnsbhetuaf',
#  'repost thelegendsofmus kiss play god thunder live tokyo 1977 music rocknrol kiss genesimmon paulstanley petercriss iiii http co wdhkqwq391',
#  'check fantast photo expo eddievanhalen icon rock photograph neilzlowzow best photo histori evh unbeliev qualiti iiii http co ye884kcvzt',
#  'repost rorygallagheroffici rori play learnt lesson german tv show beat club day 1971 iiii http co mwfyohhsbx',
#  'repost lordrarerock rememb someon realli love highwayman play live forev live studio 1995 highwayman featur countri legend johnni cash waylon jen kri kristofferson willi nelson iiii http co ax4dh8gzlg',
#  'repost thehorrorgalleri iiii http co 1chruuvldp',
#  'post photo http co e6ki6itil6',
#  'post photo http co cyoz0zypmu',
#  'repost 52graham52 iiii http co yyckcs4zob',
#  'today slash2world celebr 10th anniversari offici fan page smkc thank support cheer iiii',
#  'repost dropkickblu jame brown time live david letterman 1982 perform call best live perform televis histori iiii http co cbem70zfr',
#  'happi birthday keithrichard iiii http co qmh0qxgyg1',
#  'repost lisarosa statu liberti construct 1885 iiii http co 0dtnagzy3m',
#  'repost bizarredoctor muppet mania 10 bizarr wild snap artist sentientmuppetfactori beth frey iiii http co 6el3kdtrnj',
#  'repost thelegendsofmus aerosmith play livin edg live 1994 music rocknrol aerosmith bradwhitford joeperri tomhamilton joeykram steventyl iiii http co gtlrbeyglr',
#  'happi birthday billyfgibbon iiii http co shszc51gh6',
#  'repost eratk666 creaturet sauci lagoon mark alfrey laguna markalfrey mark alfrey art iiii http co 9iujj4sg2f',
#  'repost bjanetros artist arthur berzinsh iiii http co vp3ikayjar',
#  'repost lordrarerock seem jame gang perform walk away 1971 beat club iiii http co fmz8vqfqoy',
#  'repost mothpet ai art anim mothpet softwar werbleapp iiii http co wqecujaqfr',
#  'repost infern art witch sirin waldemar von kozak twilight time witch hour prais might time devil blood iiii http co cis7fc7rqo',
#  'happi birthday nikkisixx iiii http co wz6yklltfp',
#  'happi birthday creativ mastermind brother ashhudson ashflix n chill iiii http co ekonrnnwdp',
#  'repost bencordova guitar woodi ronwood ronniewood face ohlala thefac ronnielan britrock uk iiii http co wn4mlqnsfn',
#  'repost jess rene art bartheijlen death instaart skull skeleton darkart dark macabr mood instagood horror gore evil macabreart weekendvib iiii http co 8yvjexga1c',
#  'repost worldofdisnep dangrlab iiii http co agvxfxvpyo',
#  'thank auckland nz fit end tour southern hemispher guy amaz rain amp one book rnfnr cheer iiii',
#  'help environ plant tree creat xrayt zone nft collabor slash marta zawadzka support onetreepl limit collect 6 nft drop announc join xrayt zone discord http co zaqp6eehbx http co 4b69xytzku',
#  'repost thelegendsofmus white stripe play hardest button button live read festiv 2004 music rocknrol thewhitestrip jackwhit megwhit iiii http co uiscuuziko',
#  'repost paulrosoli last two week rais enough money protect 1000 acr rainforest thank everyon boost share especi thank everyon donat junglekeep iiii http co kvwkdvsbfv',
#  'repost bjanetros wonderwoman iiii http co powij5ohoi',
#  'repost dropkickblu chuck berri legend iiii http co hlkbpkwllv',
#  'hell crowd wellington nz tonight guy kick as thank like add 4 wonder day wellington thank super cool peopl pleasur interact genuin hospit cheer iiii']

# %% [markdown]
# ## POS Tagging

# %%
taggedWords = []

for tweet in tweetSentences:
    # Word tokenizers is used to find the words
    # and punctuation in a string
    wordList = nltk.word_tokenize(tweet)

    #  Using a Tagger. Which is part-of-speech
    # tagger or POS-tagger.
    taggedWords.append(nltk.pos_tag(wordList))

# %%
len(taggedWords)
# Out:
# 100

# %%
taggedWords
# Out:
# [[('rip', 'NN'),
#   ('tomverlain', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('w40igeqmkk', 'NN')],
#  [('repost', 'NN'),
#   ('vintag', 'NN'),
#   ('chees', 'VBZ'),
#   ('shesjustdrawnthatway', 'RB'),
#   ('terrygilliam', 'JJ'),
#   ('montypython', 'NNS'),
#   ('legend', 'VBP'),
#   ('1960', 'CD'),
#   ('1970', 'CD'),
#   ('vintagechees', 'NNS'),
#   ('iiii', 'VBP'),
#   ('http', 'JJ'),
#   ('co', 'NN'),
#   ('2hpfzj1jvm', 'CD')],
#  [('repost', 'NN'),
#   ('thehorrorgalleri', 'NN'),
#   ('follow', 'VBP'),
#   ('u', 'JJ'),
#   ('thehorrorgalleri', 'NN'),
#   ('peligrosovalley', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('xkpm5ruwp3', 'NN')],
#  [('repost', 'NN'),
#   ('jess', 'NN'),
#   ('rene', 'JJ'),
#   ('art', 'NN'),
#   ('witch', 'NN'),
#   ('witchcraft', 'NN'),
#   ('instaart', 'NN'),
#   ('macabr', 'VBZ'),
#   ('macabreart', 'JJ'),
#   ('artist', 'JJ'),
#   ('darkart', 'NN'),
#   ('dark', 'NN'),
#   ('instagood', 'NN'),
#   ('salem', 'NN'),
#   ('joseph', 'NN'),
#   ('tomanek', 'NN'),
#   ('philip', 'NN'),
#   ('hofmann', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wvuuumxzll', 'NN')],
#  [('repost', 'NN'),
#   ('bjanetros', 'NNS'),
#   ('kostl', 'VBP'),
#   ('laugh', 'IN'),
#   ('dead', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('cgv2hmyl1i', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('vjjloc4scg', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('2y6cfktrvw', 'CD')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('a8nkjpfqho', 'NN')],
#  [('repost', 'NN'),
#   ('bizarredoctor', 'NN'),
#   ('season', 'NN'),
#   ('witch', 'NN'),
#   ('sound', 'NN'),
#   ('artist', 'JJ'),
#   ('minelauvart', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('jspww6de3k', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('steveadl', 'VBD'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('q2hjtdrmsa', 'NN')],
#  [('repost', 'NN'),
#   ('patfromstoke1', 'NN'),
#   ('repost', 'NN'),
#   ('fakedream', 'NN'),
#   ('ai', 'VBP'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('spfo4fhakc', 'NN')],
#  [('repost', 'NN'),
#   ('bjanetros', 'NNS'),
#   ('artist', 'VBP'),
#   ('trinitycatdelin', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('9lgrwvg1nj', 'CD')],
#  [('repost', 'NN'),
#   ('jayprehistoricpet', 'NN'),
#   ('one', 'CD'),
#   ('absolut', 'NN'),
#   ('giant', 'NN'),
#   ('komodo', 'VBD'),
#   ('dragon', 'NN'),
#   ('seem', 'VBP'),
#   ('like', 'IN'),
#   ('live', 'JJ'),
#   ('dinosaur', 'NN'),
#   ('run', 'VB'),
#   ('laura', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('qc9jsxubif', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('carl', 'NN'),
#   ('perkin', 'FW'),
#   ('play', 'VB'),
#   ('honey', 'NN'),
#   ('live', 'JJ'),
#   ('1956', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('carlperkin', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('3r6xlhprov', 'CD')],
#  [('http', 'NN'), ('co', 'NN'), ('azjzxpfqsi', 'NN'), ('iiii', 'NN')],
#  [('repost', 'NN'),
#   ('worldofdisnep', 'NN'),
#   ('imadeej', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('5couafjtl6', 'CD')],
#  [('rip', 'NN'),
#   ('davidcrosbi', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('vblwdqdcj0', 'NN')],
#  [('art', 'NN'),
#   ('xoticartwork', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('hstneis1qm', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('stone', 'NN'),
#   ('templ', 'NN'),
#   ('pilot', 'NN'),
#   ('play', 'VB'),
#   ('crackerman', 'JJ'),
#   ('live', 'JJ'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('stonetemplepilot', 'NN'),
#   ('scottweiland', 'NN'),
#   ('deandeleo', 'NN'),
#   ('robertdeleo', 'NN'),
#   ('ericketz', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('bizzg3udv3', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('micktaylor', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('jstmsi2t2z', 'NN')],
#  [('avail', 'JJ'),
#   ('new', 'JJ'),
#   ('collect', 'NN'),
#   ('slash', 'JJ'),
#   ('standard', 'NN'),
#   ('edit', 'NN'),
#   ('offer', 'NN'),
#   ('wide', 'JJ'),
#   ('access', 'NN'),
#   ('version', 'NN'),
#   ('book', 'NN'),
#   ('featur', 'VBD'),
#   ('364', 'CD'),
#   ('page', 'NN'),
#   ('hardcov', 'VBD'),
#   ('240', 'CD'),
#   ('x', 'JJ'),
#   ('340', 'CD'),
#   ('mm', 'JJ'),
#   ('9', 'CD'),
#   ('45', 'CD'),
#   ('x', 'NN'),
#   ('13', 'CD'),
#   ('39', 'CD'),
#   ('slashnew', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('pgrlnjuedi', 'NN')],
#  [('repost', 'NN'),
#   ('crave', 'VBP'),
#   ('wild', 'JJ'),
#   ('knock', 'NN'),
#   ('knock', 'NN'),
#   ('jukinmedia', 'NN'),
#   ('via', 'IN'),
#   ('bestialnatur', 'JJ'),
#   ('pay', 'NN'),
#   ('tf', 'NN'),
#   ('clock', 'NN'),
#   ('im', 'NN'),
#   ('comin', 'NN'),
#   ('collect', 'VBP'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('mg4vwhbtpt', 'NN')],
#  [('repost', 'NN'),
#   ('thewhiskyagogo', 'NN'),
#   ('59', 'CD'),
#   ('year', 'NN'),
#   ('ago', 'RB'),
#   ('whiski', 'VBD'),
#   ('born', 'JJ'),
#   ('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('whiski', 'VBD'),
#   ('go', 'VB'),
#   ('go', 'VB'),
#   ('thewhiskyagogo', 'RB'),
#   ('happybirthday', 'JJ'),
#   ('thewhiskyis59', 'JJ'),
#   ('happybirthdaywhiski', 'NN'),
#   ('whiskyjanuary16th', 'NN'),
#   ('whiskyjanuary16th1964', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ibqoe31kxt', 'NN')],
#  [('happi', 'NN'),
#   ('8th', 'CD'),
#   ('anniversari', 'NN'),
#   ('worlovesmrslash', 'NN'),
#   ('offici', 'NN'),
#   ('fan', 'NN'),
#   ('page', 'NN'),
#   ('support', 'NN'),
#   ('smkc', 'VBD'),
#   ('thank', 'JJ'),
#   ('dedic', 'JJ'),
#   ('commit', 'NN'),
#   ('time', 'NN'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('7rfq4zn1h1', 'CD')],
#  [('repost', 'NN'),
#   ('lordrarerock', 'NN'),
#   ('oh', 'IN'),
#   ('sing', 'VBG'),
#   ('joni', 'NN'),
#   ('mitchel', 'NN'),
#   ('mesmer', 'VBP'),
#   ('one', 'CD'),
#   ('largest', 'JJS'),
#   ('gather', 'NN'),
#   ('human', 'JJ'),
#   ('histori', 'NN'),
#   ('california', 'NN'),
#   ('isl', 'NN'),
#   ('wight', 'VBD'),
#   ('festiv', 'JJ'),
#   ('1970', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ytxbwlaujz', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('zakwyld', 'NNP'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('j6xyz7itxk', 'NN')],
#  [('repost', 'NN'),
#   ('jess', 'NN'),
#   ('rene', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('mzfxle6hz', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('davegrohl', 'VBZ'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('nyc26dnb6c', 'NN')],
#  [('sad', 'JJ'),
#   ('news', 'NN'),
#   ('rip', 'NN'),
#   ('robbieknievel', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('auiwmkknht', 'NN')],
#  [('repost', 'NN'),
#   ('factpil', 'NN'),
#   ('creepi', 'NN'),
#   ('creepyashel', 'NN'),
#   ('creepyasfuck', 'NN'),
#   ('creepypopcorn', 'JJ'),
#   ('popcornfac', 'NN'),
#   ('skull', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('5uyxkg9zlr', 'CD')],
#  [('repost', 'NN'),
#   ('wildattract', 'NN'),
#   ('mejdinho', 'NN'),
#   ('emerald', 'VBP'),
#   ('tree', 'JJ'),
#   ('boa', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('vlczhptdqg', 'NN')],
#  [('repost', 'NN'),
#   ('mrwupass', 'NN'),
#   ('repost', 'NN'),
#   ('liveguitarsolo', 'NN'),
#   ('rip', 'NN'),
#   ('jeff', 'NN'),
#   ('beck', 'NN'),
#   ('perfect', 'JJ'),
#   ('exampl', 'NN'),
#   ('geniu', 'NN'),
#   ('thank', 'NN'),
#   ('jb', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wjqhyhsdw', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('llsyrsevho', 'NN')],
#  [('repost', 'VB'),
#   ('zugart', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('e8jj3hufaf', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmusictv', 'NN'),
#   ('queen', 'JJ'),
#   ('stone', 'NN'),
#   ('age', 'NN'),
#   ('play', 'NN'),
#   ('sat', 'VBD'),
#   ('ocean', 'JJ'),
#   ('live', 'JJ'),
#   ('david', 'NN'),
#   ('letterman', 'NN'),
#   ('show', 'VBP'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('queensofthestoneag', 'NN'),
#   ('davegrohl', 'NN'),
#   ('joshhomm', 'NN'),
#   ('troyvanleeuwen', 'NN'),
#   ('deanfertita', 'JJ'),
#   ('michaelshuman', 'NN'),
#   ('joecastillo', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('b29tajdklu', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'JJ'),
#   ('rodstewart', 'VB'),
#   ('photo', 'NN'),
#   ('rosshalfin', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('7eu0wcdabu', 'CD')],
#  [('repost', 'NN'),
#   ('52graham52', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('oro7adrnth', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('davidjohansen', 'VB'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('fyhl2tjfnb', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('jimmypag', 'NN'),
#   ('photo', 'NN'),
#   ('rosshalfin', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('xendyoy2wu', 'NN')],
#  [('shop', 'NN'),
#   ('onlin', 'VBZ'),
#   ('get', 'VB'),
#   ('30', 'CD'),
#   ('storewid', 'JJ'),
#   ('part', 'NN'),
#   ('slash', 'NN'),
#   ('winter', 'NN'),
#   ('sale', 'NN'),
#   ('slashnew', 'VBD'),
#   ('http', 'JJ'),
#   ('co', 'NN'),
#   ('5dbmof8zlz', 'CD')],
#  [('repost', 'NN'),
#   ('guitarsdaili', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('3dvgh72osm', 'CD')],
#  [('check', 'NN'),
#   ('friend', 'NN'),
#   ('corinhardi', 'NN'),
#   ('killer', 'NN'),
#   ('seri', 'NN'),
#   ('gangsoflondon', 'NN'),
#   ('amcplu', 'IN'),
#   ('noth', 'DT'),
#   ('short', 'JJ'),
#   ('bad', 'JJ'),
#   ('as', 'IN'),
#   ('corinhardi', 'NN'),
#   ('amcplu', 'IN'),
#   ('gangsoflondon', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('b3afhca3zk', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('w6xw8bhmk3', 'NN')],
#  [('iiii', 'NN'), ('http', 'NN'), ('co', 'NN'), ('5e9bzatmyl', 'CD')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('iggi', 'NN'),
#   ('pop', 'NN'),
#   ('play', 'NN'),
#   ('lust', 'JJ'),
#   ('life', 'NN'),
#   ('live', 'JJ'),
#   ('manchest', 'NN'),
#   ('1977', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('iggypop', 'NN'),
#   ('davidbowi', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('6qwazssnj6', 'CD')],
#  [('1928', 'CD'),
#   ('photograph', 'NN'),
#   ('unknown', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('abbdk8ndy', 'NN')],
#  [('happi', 'NN'),
#   ('10', 'CD'),
#   ('year', 'NN'),
#   ('anniversari', 'RB'),
#   ('fansofslashw', 'VBD'),
#   ('10', 'CD'),
#   ('year', 'NN'),
#   ('repres', 'NNS'),
#   ('smkc', 'VBP'),
#   ('thank', 'NN'),
#   ('ongo', 'JJ'),
#   ('support', 'NN'),
#   ('time', 'NN'),
#   ('10', 'CD'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')],
#  [('repost', 'NN'),
#   ('darkmatterincorp', 'NN'),
#   ('altern', 'JJ'),
#   ('end', 'NN'),
#   ('get', 'NN'),
#   ('shirt', 'JJ'),
#   ('sticker', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('qpzdtutjiq', 'NN'),
#   ('dm', 'NN'),
#   ('commiss', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('zn7sc2b4tw', 'NN')],
#  [('repost', 'NN'),
#   ('mirror', 'NN'),
#   ('nuderobot', 'JJ'),
#   ('nuderobot', 'JJ'),
#   ('yassin', 'NN'),
#   ('cavali', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('yuiznhigxb', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('pretend', 'VBP'),
#   ('play', 'NN'),
#   ('tattoo', 'NN'),
#   ('love', 'VBP'),
#   ('boy', 'NN'),
#   ('live', 'JJ'),
#   ('1980', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('pretend', 'VBP'),
#   ('chrissiehynd', 'NN'),
#   ('martinchamb', 'NN'),
#   ('petefarndon', 'NN'),
#   ('jameshoneymanscott', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('hv9gybr80b', 'NN')],
#  [('repost', 'NN'),
#   ('bencordova', 'NN'),
#   ('guitar', 'NN'),
#   ('face', 'NN'),
#   ('rodstewartandthefac', 'VBP'),
#   ('paulmccartney', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('cpg6c2tufv', 'NN')],
#  [('repost', 'NN'),
#   ('toxictoon', 'NN'),
#   ('great', 'JJ'),
#   ('week', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ylv0l3mekb', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('promot', 'NN'),
#   ('footag', 'NN'),
#   ('sid', 'NN'),
#   ('viciou', 'NN'),
#   ('perform', 'NN'),
#   ('sex', 'NN'),
#   ('pistol', 'NN'),
#   ('cover', 'NN'),
#   ('frank', 'VBD'),
#   ('sinatra', 'JJ'),
#   ('way', 'NN'),
#   ('music', 'NN'),
#   ('punkrock', 'NN'),
#   ('sexpistol', 'NN'),
#   ('sidvici', 'NN'),
#   ('glenmatlock', 'NN'),
#   ('johnlydon', 'NN'),
#   ('paulcook', 'NN'),
#   ('stevejon', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ytwndbxmxt', 'NN')],
#  [('happi', 'RB'),
#   ('new', 'JJ'),
#   ('year', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('h2bcmzkzgu', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('tomhamilton', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('6qyw2ffd8w', 'CD')],
#  [('rt', 'NN'),
#   ('marta', 'NN'),
#   ('zawadzka', 'NN'),
#   ('help', 'NN'),
#   ('environ', 'NN'),
#   ('plant', 'NN'),
#   ('tree', 'NN'),
#   ('creat', 'NN'),
#   ('xrayt', 'NNP'),
#   ('zone', 'NN'),
#   ('nft', 'NN'),
#   ('collabor', 'NN'),
#   ('sla', 'NN'),
#   ('amp', 'NN'),
#   ('marta', 'NN'),
#   ('zawadz', 'NN')],
#  [('repost', 'NN'),
#   ('anti', 'JJ'),
#   ('cgi', 'JJ'),
#   ('war', 'NN'),
#   ('gargantua', 'NN'),
#   ('1966', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('iqy40nlmb5', 'NN')],
#  [('repost', 'NN'),
#   ('fmx', 'NN'),
#   ('motocrosss', 'NN'),
#   ('robbiemaddison', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('lj0ahj8u0c', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('yydeerl6tv', 'NN')],
#  [('repost', 'NN'),
#   ('lordrarerock', 'NN'),
#   ('whatev', 'NN'),
#   ('girl', 'NN'),
#   ('put', 'VBD'),
#   ('spell', 'RB'),
#   ('jimi', 'JJ'),
#   ('hendrix', 'NN'),
#   ('perform', 'NN'),
#   ('purpl', 'NN'),
#   ('haze', 'NN'),
#   ('atlanta', 'JJ'),
#   ('pop', 'NN'),
#   ('festiv', 'NN'),
#   ('1970', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('7bt6ukau38', 'CD')],
#  [('happi', 'NN'),
#   ('10th', 'CD'),
#   ('anniversari', 'NN'),
#   ('slashbolivia', 'JJ'),
#   ('support', 'NN'),
#   ('smkc', 'NN'),
#   ('massiv', 'NN'),
#   ('thank', 'NN'),
#   ('continu', 'NN'),
#   ('represent', 'NN'),
#   ('let', 'NN'),
#   ('go', 'VB'),
#   ('anoth', 'RB'),
#   ('10', 'CD'),
#   ('year', 'NN'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')],
#  [('repost', 'NN'),
#   ('eratk666', 'NN'),
#   ('wonkafac', 'NN'),
#   ('darkmatterincorp', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('dae7n0au5p', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('motorhead', 'JJ'),
#   ('play', 'NN'),
#   ('damag', 'NN'),
#   ('case', 'NN'),
#   ('live', 'JJ'),
#   ('2002', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('lemmykilmist', 'NN'),
#   ('philcampbel', 'NN'),
#   ('mikkeyde', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('yqtufgrwot', 'NN')],
#  [('repost', 'NN'),
#   ('blue', 'JJ'),
#   ('tshirt', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('qefkb3h54', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('larsulrich', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('2f8rrhhooe', 'CD')],
#  [('repost', 'NN'),
#   ('creep', 'NN'),
#   ('sock', 'NN'),
#   ('twilight', 'VBD'),
#   ('zone', 'CD'),
#   ('night', 'NN'),
#   ('meek', 'NN'),
#   ('1959', 'CD'),
#   ('anoth', 'NN'),
#   ('christma', 'JJ'),
#   ('speical', 'JJ'),
#   ('recommend', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('rlmvtyg8k9', 'NN')],
#  [('merri', 'NN'),
#   ('christma', 'NN'),
#   ('repost', 'NN'),
#   ('patfromstoke1', 'NN'),
#   ('repost', 'NN'),
#   ('motorhead', 'NN'),
#   ('fanlove01', 'NN'),
#   ('mot', 'NN'),
#   ('rhead', 'NN'),
#   ('lemmi', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('rnsbhetuaf', 'NN')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('kiss', 'JJ'),
#   ('play', 'NN'),
#   ('god', 'NN'),
#   ('thunder', 'NN'),
#   ('live', 'JJ'),
#   ('tokyo', 'NN'),
#   ('1977', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('kiss', 'JJ'),
#   ('genesimmon', 'NN'),
#   ('paulstanley', 'NN'),
#   ('petercriss', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wdhkqwq391', 'NN')],
#  [('check', 'NN'),
#   ('fantast', 'NN'),
#   ('photo', 'NN'),
#   ('expo', 'NN'),
#   ('eddievanhalen', 'VBN'),
#   ('icon', 'JJ'),
#   ('rock', 'NN'),
#   ('photograph', 'NN'),
#   ('neilzlowzow', 'NN'),
#   ('best', 'JJS'),
#   ('photo', 'NN'),
#   ('histori', 'NN'),
#   ('evh', 'NN'),
#   ('unbeliev', 'JJ'),
#   ('qualiti', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ye884kcvzt', 'NN')],
#  [('repost', 'NN'),
#   ('rorygallagheroffici', 'NN'),
#   ('rori', 'VBP'),
#   ('play', 'NN'),
#   ('learnt', 'NN'),
#   ('lesson', 'JJ'),
#   ('german', 'JJ'),
#   ('tv', 'NN'),
#   ('show', 'NN'),
#   ('beat', 'JJ'),
#   ('club', 'JJ'),
#   ('day', 'NN'),
#   ('1971', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('mwfyohhsbx', 'NN')],
#  [('repost', 'NN'),
#   ('lordrarerock', 'NN'),
#   ('rememb', 'NN'),
#   ('someon', 'NN'),
#   ('realli', 'NN'),
#   ('love', 'NN'),
#   ('highwayman', 'NN'),
#   ('play', 'VBP'),
#   ('live', 'JJ'),
#   ('forev', 'NN'),
#   ('live', 'JJ'),
#   ('studio', 'NN'),
#   ('1995', 'CD'),
#   ('highwayman', 'NN'),
#   ('featur', 'VBD'),
#   ('countri', 'JJ'),
#   ('legend', 'JJ'),
#   ('johnni', 'NN'),
#   ('cash', 'NN'),
#   ('waylon', 'NN'),
#   ('jen', 'NN'),
#   ('kri', 'NN'),
#   ('kristofferson', 'NN'),
#   ('willi', 'WRB'),
#   ('nelson', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('ax4dh8gzlg', 'NN')],
#  [('repost', 'NN'),
#   ('thehorrorgalleri', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('1chruuvldp', 'CD')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('e6ki6itil6', 'NN')],
#  [('post', 'NN'),
#   ('photo', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('cyoz0zypmu', 'NN')],
#  [('repost', 'NN'),
#   ('52graham52', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('yyckcs4zob', 'NN')],
#  [('today', 'NN'),
#   ('slash2world', 'VBD'),
#   ('celebr', 'NN'),
#   ('10th', 'CD'),
#   ('anniversari', 'JJ'),
#   ('offici', 'NN'),
#   ('fan', 'NN'),
#   ('page', 'NN'),
#   ('smkc', 'VBD'),
#   ('thank', 'JJ'),
#   ('support', 'NN'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')],
#  [('repost', 'NN'),
#   ('dropkickblu', 'NN'),
#   ('jame', 'NN'),
#   ('brown', 'JJ'),
#   ('time', 'NN'),
#   ('live', 'JJ'),
#   ('david', 'NN'),
#   ('letterman', 'NN'),
#   ('1982', 'CD'),
#   ('perform', 'NN'),
#   ('call', 'NN'),
#   ('best', 'RBS'),
#   ('live', 'JJ'),
#   ('perform', 'NN'),
#   ('televis', 'NN'),
#   ('histori', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('cbem70zfr', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('keithrichard', 'NNP'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('qmh0qxgyg1', 'NN')],
#  [('repost', 'NN'),
#   ('lisarosa', 'NN'),
#   ('statu', 'NN'),
#   ('liberti', 'NN'),
#   ('construct', 'NN'),
#   ('1885', 'CD'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('0dtnagzy3m', 'CD')],
#  [('repost', 'NN'),
#   ('bizarredoctor', 'NN'),
#   ('muppet', 'NN'),
#   ('mania', 'VBD'),
#   ('10', 'CD'),
#   ('bizarr', 'NN'),
#   ('wild', 'JJ'),
#   ('snap', 'JJ'),
#   ('artist', 'NN'),
#   ('sentientmuppetfactori', 'NN'),
#   ('beth', 'VBZ'),
#   ('frey', 'JJ'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('6el3kdtrnj', 'CD')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'NN'),
#   ('aerosmith', 'NN'),
#   ('play', 'NN'),
#   ('livin', 'VBZ'),
#   ('edg', 'RB'),
#   ('live', 'JJ'),
#   ('1994', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('aerosmith', 'NN'),
#   ('bradwhitford', 'NN'),
#   ('joeperri', 'NN'),
#   ('tomhamilton', 'NN'),
#   ('joeykram', 'NN'),
#   ('steventyl', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('gtlrbeyglr', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('billyfgibbon', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('shszc51gh6', 'NN')],
#  [('repost', 'NN'),
#   ('eratk666', 'NN'),
#   ('creaturet', 'NN'),
#   ('sauci', 'NN'),
#   ('lagoon', 'NN'),
#   ('mark', 'NN'),
#   ('alfrey', 'NN'),
#   ('laguna', 'NN'),
#   ('markalfrey', 'NN'),
#   ('mark', 'NN'),
#   ('alfrey', 'JJ'),
#   ('art', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('9iujj4sg2f', 'CD')],
#  [('repost', 'NN'),
#   ('bjanetros', 'NNS'),
#   ('artist', 'VBP'),
#   ('arthur', 'IN'),
#   ('berzinsh', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('vp3ikayjar', 'NN')],
#  [('repost', 'NN'),
#   ('lordrarerock', 'NN'),
#   ('seem', 'VBP'),
#   ('jame', 'NN'),
#   ('gang', 'NN'),
#   ('perform', 'NN'),
#   ('walk', 'VBP'),
#   ('away', 'RB'),
#   ('1971', 'CD'),
#   ('beat', 'NN'),
#   ('club', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('fmz8vqfqoy', 'NN')],
#  [('repost', 'NN'),
#   ('mothpet', 'NN'),
#   ('ai', 'VBP'),
#   ('art', 'NN'),
#   ('anim', 'NN'),
#   ('mothpet', 'NN'),
#   ('softwar', 'JJ'),
#   ('werbleapp', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wqecujaqfr', 'NN')],
#  [('repost', 'NN'),
#   ('infern', 'JJ'),
#   ('art', 'NN'),
#   ('witch', 'NN'),
#   ('sirin', 'NN'),
#   ('waldemar', 'NN'),
#   ('von', 'NN'),
#   ('kozak', 'VB'),
#   ('twilight', 'JJ'),
#   ('time', 'NN'),
#   ('witch', 'VB'),
#   ('hour', 'NN'),
#   ('prais', 'NN'),
#   ('might', 'MD'),
#   ('time', 'NN'),
#   ('devil', 'VB'),
#   ('blood', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('cis7fc7rqo', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('nikkisixx', 'IN'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wz6yklltfp', 'NN')],
#  [('happi', 'NN'),
#   ('birthday', 'NN'),
#   ('creativ', 'NN'),
#   ('mastermind', 'NN'),
#   ('brother', 'NN'),
#   ('ashhudson', 'NN'),
#   ('ashflix', 'NN'),
#   ('n', 'NN'),
#   ('chill', 'NN'),
#   ('iiii', 'VB'),
#   ('http', 'JJ'),
#   ('co', 'NN'),
#   ('ekonrnnwdp', 'NN')],
#  [('repost', 'NN'),
#   ('bencordova', 'NN'),
#   ('guitar', 'NN'),
#   ('woodi', 'NN'),
#   ('ronwood', 'NN'),
#   ('ronniewood', 'NN'),
#   ('face', 'NN'),
#   ('ohlala', 'VBP'),
#   ('thefac', 'NN'),
#   ('ronnielan', 'NN'),
#   ('britrock', 'NN'),
#   ('uk', 'JJ'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('wn4mlqnsfn', 'NN')],
#  [('repost', 'NN'),
#   ('jess', 'NN'),
#   ('rene', 'JJ'),
#   ('art', 'NN'),
#   ('bartheijlen', 'VBN'),
#   ('death', 'NN'),
#   ('instaart', 'NN'),
#   ('skull', 'VBP'),
#   ('skeleton', 'NN'),
#   ('darkart', 'NN'),
#   ('dark', 'NN'),
#   ('macabr', 'NN'),
#   ('mood', 'NN'),
#   ('instagood', 'NN'),
#   ('horror', 'NN'),
#   ('gore', 'NN'),
#   ('evil', 'JJ'),
#   ('macabreart', 'NN'),
#   ('weekendvib', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'VBD'),
#   ('co', 'JJ'),
#   ('8yvjexga1c', 'CD')],
#  [('repost', 'NN'),
#   ('worldofdisnep', 'NN'),
#   ('dangrlab', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('agvxfxvpyo', 'NN')],
#  [('thank', 'NN'),
#   ('auckland', 'NN'),
#   ('nz', 'NN'),
#   ('fit', 'JJ'),
#   ('end', 'VB'),
#   ('tour', 'NN'),
#   ('southern', 'JJ'),
#   ('hemispher', 'NN'),
#   ('guy', 'NN'),
#   ('amaz', 'NN'),
#   ('rain', 'NN'),
#   ('amp', 'IN'),
#   ('one', 'CD'),
#   ('book', 'NN'),
#   ('rnfnr', 'NN'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')],
#  [('help', 'NN'),
#   ('environ', 'NN'),
#   ('plant', 'NN'),
#   ('tree', 'NN'),
#   ('creat', 'NN'),
#   ('xrayt', 'NNP'),
#   ('zone', 'NN'),
#   ('nft', 'NN'),
#   ('collabor', 'NN'),
#   ('slash', 'NN'),
#   ('marta', 'NN'),
#   ('zawadzka', 'NN'),
#   ('support', 'NN'),
#   ('onetreepl', 'VBD'),
#   ('limit', 'NN'),
#   ('collect', 'NN'),
#   ('6', 'CD'),
#   ('nft', 'JJ'),
#   ('drop', 'NN'),
#   ('announc', 'NN'),
#   ('join', 'NN'),
#   ('xrayt', 'NNP'),
#   ('zone', 'NN'),
#   ('discord', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('zaqp6eehbx', 'NNP'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('4b69xytzku', 'CD')],
#  [('repost', 'NN'),
#   ('thelegendsofmus', 'JJ'),
#   ('white', 'JJ'),
#   ('stripe', 'NN'),
#   ('play', 'NN'),
#   ('hardest', 'JJS'),
#   ('button', 'NN'),
#   ('button', 'NN'),
#   ('live', 'VBP'),
#   ('read', 'VBN'),
#   ('festiv', 'JJ'),
#   ('2004', 'CD'),
#   ('music', 'NN'),
#   ('rocknrol', 'NN'),
#   ('thewhitestrip', 'NN'),
#   ('jackwhit', 'NN'),
#   ('megwhit', 'VBD'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('uiscuuziko', 'NN')],
#  [('repost', 'NN'),
#   ('paulrosoli', 'NNS'),
#   ('last', 'JJ'),
#   ('two', 'CD'),
#   ('week', 'NN'),
#   ('rais', 'NNS'),
#   ('enough', 'JJ'),
#   ('money', 'NN'),
#   ('protect', 'NN'),
#   ('1000', 'CD'),
#   ('acr', 'NN'),
#   ('rainforest', 'NN'),
#   ('thank', 'NN'),
#   ('everyon', 'NN'),
#   ('boost', 'NN'),
#   ('share', 'NN'),
#   ('especi', 'JJ'),
#   ('thank', 'NN'),
#   ('everyon', 'NN'),
#   ('donat', 'NN'),
#   ('junglekeep', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('kvwkdvsbfv', 'NN')],
#  [('repost', 'NN'),
#   ('bjanetros', 'NNS'),
#   ('wonderwoman', 'VBP'),
#   ('iiii', 'JJ'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('powij5ohoi', 'NN')],
#  [('repost', 'NN'),
#   ('dropkickblu', 'NN'),
#   ('chuck', 'NN'),
#   ('berri', 'JJ'),
#   ('legend', 'NN'),
#   ('iiii', 'NN'),
#   ('http', 'NN'),
#   ('co', 'NN'),
#   ('hlkbpkwllv', 'NN')],
#  [('hell', 'NN'),
#   ('crowd', 'VBZ'),
#   ('wellington', 'WP'),
#   ('nz', 'JJ'),
#   ('tonight', 'NN'),
#   ('guy', 'NN'),
#   ('kick', 'NN'),
#   ('as', 'IN'),
#   ('thank', 'NN'),
#   ('like', 'IN'),
#   ('add', '$'),
#   ('4', 'CD'),
#   ('wonder', 'JJR'),
#   ('day', 'NN'),
#   ('wellington', 'VBD'),
#   ('thank', 'JJ'),
#   ('super', 'JJ'),
#   ('cool', 'NN'),
#   ('peopl', 'NN'),
#   ('pleasur', 'NN'),
#   ('interact', 'NN'),
#   ('genuin', 'NN'),
#   ('hospit', 'NN'),
#   ('cheer', 'NN'),
#   ('iiii', 'NN')]]
