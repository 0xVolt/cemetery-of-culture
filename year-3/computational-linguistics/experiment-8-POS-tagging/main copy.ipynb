# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import re

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from gensim.models import Word2Vec

# %% [markdown]
# ## Read tweets

# %%
df = pd.read_csv(r'../assets/data/tweets.csv')

tweets = df['text']

tweets
# Out:
# 0              RIP #TomVerlaine https://t.co/w40iGeqmKK
# 1     Reposted from @vintage.cheese #shesjustdrawnth...
# 2     Reposted from @thehorrorgallery 😂🤣 🔥 \n\nFollo...
# 3     Reposted from @jess_rene_ #art #witch #witchcr...
# 4     Reposted from @bjanetrose 🥀 @kostle_laugh_with...
#                             ...
# 95    Reposted from @thelegendsofmusic The White Str...
# 96    Reposted from @paulrosolie  In the last two we...
# 97    Reposted from @bjanetrose 🥀 #wonderwoman 🥀  ii...
# 98    Reposted from dropkickblues Chuck Berry, what ...
# 99    Hell of a crowd in Wellington, NZ tonight, you...
# Name: text, Length: 100, dtype: object

# %% [markdown]
# ## Pre-process tweets

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

tweetList = []
tweetSentences = []

stopWords = set(stopwords.words('english'))

for i, tweet in enumerate(tweets):
    # Convert the tweet to lowercase using REGEX
    for f in re.findall("([A-Z]+)", tweet):
        tweet = tweet.replace(f, f.lower())

    # Removing special characters and replacing them with a space
    tweet = re.sub("[^A-Za-z0-9]", " ", tweet, 0, re.IGNORECASE)
    
    # From a single sentence, store all the words 
    wordsInTweet = nltk.word_tokenize(tweet)
    
    # Filter out all the stop words
    wordsInTweet = [word for word in wordsInTweet if word not in stopWords]
    
    # Lemmatize each of the tweets
    wordsInTweet = [lemmatizer.lemmatize(word) for word in wordsInTweet]
    
    # Append them to a list
    tweetList.append(wordsInTweet)
    
    # Remake the sentences after removing the stop words
    tweetSentences.append(' '.join(wordsInTweet))

# %%
tweetList
# Out:
# [['rip', 'tomverlaine', 'http', 'co', 'w40igeqmkk'],
#  ['reposted',
#   'vintage',
#   'cheese',
#   'shesjustdrawnthatway',
#   'terrygilliam',
#   'montypython',
#   'legend',
#   '1960s',
#   '1970s',
#   'vintagecheese',
#   'iiii',
#   'http',
#   'co',
#   '2hpfzj1jVM'],
#  ['reposted',
#   'thehorrorgallery',
#   'follow',
#   'u',
#   'thehorrorgallery',
#   'peligrosovalley',
#   'iiii',
#   'http',
#   'co',
#   'xkpm5rUwp3'],
#  ['reposted',
#   'jess',
#   'rene',
#   'art',
#   'witch',
#   'witchcraft',
#   'instaart',
#   'macabre',
#   'macabreart',
#   'artist',
#   'darkart',
#   'dark',
#   'instagood',
#   'salem',
#   'joseph',
#   'tomanek',
#   'philip',
#   'hofmanner',
#   'iiii',
#   'http',
#   'co',
#   'wvuuumxzll'],
#  ['reposted',
#   'bjanetrose',
#   'kostle',
#   'laugh',
#   'dead',
#   'iiii',
#   'http',
#   'co',
#   'cgv2hmyl1i'],
#  ['posted', 'photo', 'http', 'co', 'Vjjloc4scg'],
#  ['posted', 'photo', 'http', 'co', '2y6cfktrvw'],
#  ['posted', 'photo', 'http', 'co', 'a8nKjpfqho'],
#  ['reposted',
#   'bizarredoctor',
#   'season',
#   'witch',
#   'sound',
#   'artist',
#   'minelauvart',
#   'iiii',
#   'http',
#   'co',
#   'jspww6de3k'],
#  ['happy', 'birthday', 'steveadler', 'iiii', 'http', 'co', 'q2hjtdrmsa'],
#  ['reposted',
#   'patfromstoke1',
#   'reposted',
#   'fakedreams',
#   'ai',
#   'iiii',
#   'http',
#   'co',
#   'spfo4fhakc'],
#  ['reposted',
#   'bjanetrose',
#   'artist',
#   'trinitycatdeline',
#   'iiii',
#   'http',
#   'co',
#   '9lgrwvg1nj'],
#  ['reposted',
#   'jayprehistoricpets',
#   'one',
#   'absolutely',
#   'giant',
#   'komodo',
#   'dragon',
#   'seems',
#   'like',
#   'living',
#   'dinosaur',
#   'run',
#   'laura',
#   'iiii',
#   'http',
#   'co',
#   'qc9jsxubif'],
#  ['reposted',
#   'thelegendsofmusic',
#   'carl',
#   'perkins',
#   'playing',
#   'honey',
#   'live',
#   '1956',
#   'music',
#   'rockNroll',
#   'carlperkins',
#   'iiii',
#   'http',
#   'co',
#   '3r6xlhprov'],
#  ['http', 'co', 'azjzxpfqsi', 'iiii'],
#  ['reposted', 'worldofdisnep', 'imadeej', 'iiii', 'http', 'co', '5couAFjtl6'],
#  ['rip', 'davidcrosby', 'http', 'co', 'vblwdqdcj0'],
#  ['art', 'xoticartwork', 'iiii', 'http', 'co', 'hstneis1qm'],
#  ['reposted',
#   'thelegendsofmusic',
#   'stone',
#   'temple',
#   'pilot',
#   'playing',
#   'crackerman',
#   'live',
#   'music',
#   'rockNroll',
#   'stonetemplepilots',
#   'scottweiland',
#   'deandeleo',
#   'robertdeleo',
#   'ericketz',
#   'iiii',
#   'http',
#   'co',
#   'bizzg3udV3'],
#  ['happy', 'birthday', 'micktaylor', 'iiii', 'http', 'co', 'jstmsi2t2z'],
#  ['available',
#   'neW',
#   'collection',
#   'slash',
#   'standard',
#   'edition',
#   'offer',
#   'widely',
#   'accessible',
#   'version',
#   'book',
#   'featuring',
#   '364',
#   'page',
#   'hardcover',
#   '240',
#   'x',
#   '340',
#   'mm',
#   '9',
#   '45',
#   'x',
#   '13',
#   '39',
#   'slashnews',
#   'http',
#   'co',
#   'pgrlnjUeDY'],
#  ['reposted',
#   'crave',
#   'wild',
#   'knock',
#   'knock',
#   'jukinmedia',
#   'via',
#   'bestialnature',
#   'pay',
#   'tf',
#   'clock',
#   'im',
#   'comin',
#   'collect',
#   'iiii',
#   'http',
#   'co',
#   'mg4vwhbtpt'],
#  ['reposted',
#   'thewhiskyagogo',
#   '59',
#   'year',
#   'ago',
#   'whisky',
#   'born',
#   'happy',
#   'birthday',
#   'whisky',
#   'go',
#   'go',
#   'thewhiskyagogo',
#   'happybirthday',
#   'thewhiskyis59',
#   'happybirthdaywhisky',
#   'whiskyjanuary16th',
#   'whiskyjanuary16th1964',
#   'iiii',
#   'http',
#   'co',
#   'ibqoe31kxt'],
#  ['happy',
#   '8th',
#   'anniversary',
#   'worlovesmrslash',
#   'official',
#   'fan',
#   'page',
#   'supporting',
#   'smKC',
#   'thanks',
#   'dedicated',
#   'commitment',
#   'time',
#   'cheer',
#   'iiii'],
#  ['posted', 'photo', 'http', 'co', '7rfq4zn1h1'],
#  ['reposted',
#   'lordrarerock',
#   'oh',
#   'sings',
#   'joni',
#   'mitchell',
#   'mesmerizes',
#   'one',
#   'largest',
#   'gathering',
#   'human',
#   'history',
#   'california',
#   'isle',
#   'wight',
#   'festival',
#   '1970',
#   'iiii',
#   'http',
#   'co',
#   'ytXBwlaujz'],
#  ['happy', 'birthday', 'zakwylde', 'iiii', 'http', 'co', 'j6XYz7itxk'],
#  ['repost', 'jess', 'rene', 'iiii', 'http', 'co', 'mzfxle6hze'],
#  ['happy', 'birthday', 'davegrohl', 'iiii', 'http', 'co', 'nyc26dNb6c'],
#  ['sad', 'news', 'rip', 'robbieknievel', 'http', 'co', 'auIWmkkNht'],
#  ['reposted',
#   'factpilers',
#   'creepy',
#   'creepyashell',
#   'creepyasfuck',
#   'creepypopcorn',
#   'popcornfaces',
#   'skull',
#   'iiii',
#   'http',
#   'co',
#   '5uyxkg9ZLr'],
#  ['reposted',
#   'wildattractions',
#   'mejdinho',
#   'emerald',
#   'tree',
#   'boa',
#   'iiii',
#   'http',
#   'co',
#   'vlczhptdqg'],
#  ['reposted',
#   'mrwupass',
#   'repost',
#   'liveguitarsolos',
#   'rIp',
#   'jeff',
#   'beck',
#   'perfect',
#   'example',
#   'genius',
#   'thank',
#   'jb',
#   'http',
#   'co',
#   'wjqhyhSdwe'],
#  ['posted', 'photo', 'http', 'co', 'llsyrsevho'],
#  ['reposted', 'zugart', 'iiii', 'http', 'co', 'e8jj3hufaf'],
#  ['reposted',
#   'thelegendsofmusictv',
#   'queen',
#   'stone',
#   'age',
#   'playing',
#   'sat',
#   'ocean',
#   'live',
#   'david',
#   'letterman',
#   'show',
#   'music',
#   'rockNroll',
#   'queensofthestoneage',
#   'davegrohl',
#   'joshhomme',
#   'troyvanleeuwen',
#   'deanfertita',
#   'michaelshuman',
#   'joecastillo',
#   'iiii',
#   'http',
#   'co',
#   'b29tajdklu'],
#  ['happy',
#   'birthday',
#   'rodstewart',
#   'photo',
#   'rosshalfin',
#   'iiii',
#   'http',
#   'co',
#   '7eu0wcDAbu'],
#  ['reposted', '52graham52', 'iiii', 'http', 'co', 'OrO7adrnth'],
#  ['happy', 'birthday', 'davidjohansen', 'iiii', 'http', 'co', 'fyhl2Tjfnb'],
#  ['happy',
#   'birthday',
#   'jimmypage',
#   'photo',
#   'rosshalfin',
#   'iiii',
#   'http',
#   'co',
#   'xendyoy2wu'],
#  ['shop',
#   'online',
#   'get',
#   '30',
#   'storewide',
#   'part',
#   'slash',
#   'winter',
#   'sale',
#   'slashnews',
#   'http',
#   'co',
#   '5dbmof8zlz'],
#  ['reposted', 'guitarsdaily', 'iiii', 'http', 'co', '3dvgh72osm'],
#  ['check',
#   'friend',
#   'corinhardy',
#   'killer',
#   'series',
#   'gangsoflondon',
#   'amcplus',
#   'nothing',
#   'short',
#   'bad',
#   'as',
#   'corinhardy',
#   'amcplus',
#   'gangsoflondon',
#   'iiii',
#   'http',
#   'co',
#   'b3afhcA3zk'],
#  ['posted', 'photo', 'http', 'co', 'w6xw8bhmk3'],
#  ['iiii', 'http', 'co', '5e9bzatmyl'],
#  ['reposted',
#   'thelegendsofmusic',
#   'iggy',
#   'pop',
#   'playing',
#   'lust',
#   'life',
#   'live',
#   'manchester',
#   '1977',
#   'music',
#   'rockNroll',
#   'iggypop',
#   'davidbowie',
#   'iiii',
#   'http',
#   'co',
#   '6qwazssnj6'],
#  ['1928', 'photographer', 'unknown', 'iiii', 'http', 'co', 'abbdk8ndye'],
#  ['happy',
#   '10',
#   'year',
#   'anniversary',
#   'fansofslashw',
#   '10',
#   'year',
#   'representing',
#   'sMKC',
#   'thanks',
#   'ongoing',
#   'support',
#   'time',
#   '10',
#   'cheer',
#   'iiii'],
#  ['reposted',
#   'darkmatterincorp',
#   'alternate',
#   'ending',
#   'get',
#   'shirt',
#   'sticker',
#   'http',
#   'co',
#   'qpzdtutjiq',
#   'dm',
#   'commission',
#   'iiii',
#   'http',
#   'co',
#   'zn7sc2b4tw'],
#  ['reposted',
#   'mirror',
#   'NUDErObOT',
#   'nuderobot',
#   'yassine',
#   'cavalier',
#   'iiii',
#   'http',
#   'co',
#   'yuiznhigxb'],
#  ['reposted',
#   'thelegendsofmusic',
#   'pretender',
#   'playing',
#   'tattoo',
#   'love',
#   'boy',
#   'live',
#   '1980',
#   'music',
#   'rockNroll',
#   'pretender',
#   'chrissiehynde',
#   'martinchambers',
#   'petefarndon',
#   'jameshoneymanscott',
#   'iiii',
#   'http',
#   'co',
#   'hV9gYbr80b'],
#  ['reposted',
#   'bencordova',
#   'guitar',
#   'face',
#   'rodstewartandthefaces',
#   'paulmccartney',
#   'iiii',
#   'http',
#   'co',
#   'cpg6c2tufv'],
#  ['reposted',
#   'toxictoons',
#   'great',
#   'week',
#   'iiii',
#   'http',
#   'co',
#   'ylv0l3mekb'],
#  ['reposted',
#   'thelegendsofmusic',
#   'promotional',
#   'footage',
#   'sid',
#   'vicious',
#   'performing',
#   'sex',
#   'pistol',
#   'cover',
#   'frank',
#   'sinatra',
#   'way',
#   'music',
#   'punkrock',
#   'sexpistols',
#   'sidvicious',
#   'glenmatlock',
#   'johnlydon',
#   'paulcook',
#   'stevejones',
#   'iiii',
#   'http',
#   'co',
#   'ytwndbxmxt'],
#  ['happy', 'new', 'year', 'iiii', 'http', 'co', 'h2bcmzkzgu'],
#  ['happy', 'birthday', 'tomhamilton', 'iiii', 'http', 'co', '6qyw2ffd8w'],
#  ['rt',
#   'marta',
#   'zawadzka',
#   'help',
#   'environment',
#   'planting',
#   'tree',
#   'created',
#   'xrayted',
#   'zone',
#   'NFt',
#   'collaboration',
#   'slas',
#   'amp',
#   'marta',
#   'zawadz'],
#  ['reposted',
#   'anti',
#   'cgi',
#   'war',
#   'gargantua',
#   '1966',
#   'iiii',
#   'http',
#   'co',
#   'iqy40nlmb5'],
#  ['reposted',
#   'fmx',
#   'motocrosss',
#   'robbiemaddison',
#   'iiii',
#   'http',
#   'co',
#   'lj0ahj8u0c'],
#  ['posted', 'photo', 'http', 'co', 'yydeerl6tv'],
#  ['reposted',
#   'lordrarerock',
#   'WhaTEVEr',
#   'GIrL',
#   'put',
#   'spell',
#   'jimi',
#   'hendrix',
#   'performing',
#   'purple',
#   'haze',
#   'atlanta',
#   'pop',
#   'festival',
#   '1970',
#   'iiii',
#   'http',
#   'co',
#   '7bt6ukau38'],
#  ['happy',
#   '10th',
#   'anniversary',
#   'slashbolivia',
#   'supporting',
#   'smKC',
#   'massive',
#   'thanks',
#   'continued',
#   'representation',
#   'let',
#   'go',
#   'another',
#   '10',
#   'year',
#   'cheer',
#   'iiii'],
#  ['reposted',
#   'eratk666',
#   'wonkaface',
#   'darkmatterincorp',
#   'iiii',
#   'http',
#   'co',
#   'dae7n0au5p'],
#  ['reposted',
#   'thelegendsofmusic',
#   'motorhead',
#   'playing',
#   'damage',
#   'case',
#   'live',
#   '2002',
#   'music',
#   'rockNroll',
#   'lemmykilmister',
#   'philcampbell',
#   'mikkeydee',
#   'iiii',
#   'http',
#   'co',
#   'yqtufgrWot'],
#  ['reposted', 'blue', 'tshirt', 'iiii', 'http', 'co', 'qefkb3h54e'],
#  ['happy', 'birthday', 'larsulrich', 'iiii', 'http', 'co', '2f8rRhhooe'],
#  ['reposted',
#   'creep',
#   'sock',
#   'twilight',
#   'zone',
#   'night',
#   'meek',
#   '1959',
#   'another',
#   'christmas',
#   'speical',
#   'recommendation',
#   'iiii',
#   'http',
#   'co',
#   'rLmVtYg8k9'],
#  ['merry',
#   'christmas',
#   'reposted',
#   'patfromstoke1',
#   'reposted',
#   'motorhead',
#   'fanlove01',
#   'mot',
#   'rhead',
#   'lemmy',
#   'iiii',
#   'http',
#   'co',
#   'rNsbhetuaf'],
#  ['reposted',
#   'thelegendsofmusic',
#   'kiss',
#   'playing',
#   'god',
#   'thunder',
#   'live',
#   'tokyo',
#   '1977',
#   'music',
#   'rockNroll',
#   'kiss',
#   'genesimmons',
#   'paulstanley',
#   'petercriss',
#   'iiii',
#   'http',
#   'co',
#   'wdhkQwq391'],
#  ['check',
#   'fantastic',
#   'photo',
#   'expose',
#   'eddievanhalen',
#   'iconic',
#   'rock',
#   'photographer',
#   'neilzlowzower',
#   'best',
#   'photo',
#   'history',
#   'evh',
#   'unbelievable',
#   'quality',
#   'iiii',
#   'http',
#   'co',
#   'ye884KCvzt'],
#  ['reposted',
#   'rorygallagherofficial',
#   'rory',
#   'playing',
#   'learnt',
#   'lesson',
#   'german',
#   'tv',
#   'show',
#   'beat',
#   'club',
#   'day',
#   '1971',
#   'iiii',
#   'http',
#   'co',
#   'mwfyohhsbx'],
#  ['reposted',
#   'lordrarerock',
#   'rEMEMBEr',
#   'someone',
#   'rEAllY',
#   'love',
#   'highwayman',
#   'play',
#   'live',
#   'forever',
#   'live',
#   'studio',
#   '1995',
#   'highwayman',
#   'featured',
#   'country',
#   'legend',
#   'johnny',
#   'cash',
#   'waylon',
#   'jennings',
#   'kris',
#   'kristofferson',
#   'willie',
#   'nelson',
#   'iiii',
#   'http',
#   'co',
#   'ax4dh8GZlG'],
#  ['reposted', 'thehorrorgallery', 'iiii', 'http', 'co', '1CHruuvldp'],
#  ['posted', 'photo', 'http', 'co', 'e6ki6itil6'],
#  ['posted', 'photo', 'http', 'co', 'cyoz0zypmu'],
#  ['reposted', '52graham52', 'iiii', 'http', 'co', 'yyckcs4zob'],
#  ['today',
#   'slash2world',
#   'celebrates',
#   '10th',
#   'anniversary',
#   'official',
#   'fan',
#   'page',
#   'smkc',
#   'thank',
#   'support',
#   'cheer',
#   'iiii'],
#  ['reposted',
#   'dropkickblues',
#   'james',
#   'brown',
#   'time',
#   'live',
#   'david',
#   'letterman',
#   '1982',
#   'performance',
#   'called',
#   'best',
#   'live',
#   'performance',
#   'television',
#   'history',
#   'iiii',
#   'http',
#   'co',
#   'cbem70zfrs'],
#  ['happy', 'birthday', 'keithrichards', 'iiii', 'http', 'co', 'qmh0qxgyg1'],
#  ['reposted',
#   'lisarosa',
#   'statue',
#   'liberty',
#   'construction',
#   '1885',
#   'iiii',
#   'http',
#   'co',
#   '0DtNagzy3m'],
#  ['reposted',
#   'bizarredoctor',
#   'muppet',
#   'mania',
#   '10',
#   'bizarre',
#   'wild',
#   'snap',
#   'artist',
#   'sentientmuppetfactory',
#   'beth',
#   'frey',
#   'iiii',
#   'http',
#   'co',
#   '6el3kdtrnj'],
#  ['reposted',
#   'thelegendsofmusic',
#   'aerosmith',
#   'playing',
#   'livin',
#   'edge',
#   'live',
#   '1994',
#   'music',
#   'rockNroll',
#   'aerosmith',
#   'bradwhitford',
#   'joeperry',
#   'tomhamilton',
#   'joeykramer',
#   'steventyler',
#   'iiii',
#   'http',
#   'co',
#   'gtlrbeYGlr'],
#  ['happy', 'birthday', 'billyfgibbons', 'iiii', 'http', 'co', 'shszc51gh6'],
#  ['reposted',
#   'eratk666',
#   'creaturete',
#   'saucy',
#   'lagoon',
#   'mark',
#   'alfreys',
#   'laguna',
#   'marKalFrEY',
#   'mark',
#   'alfrey',
#   'art',
#   'iiii',
#   'http',
#   'co',
#   '9iujj4sG2f'],
#  ['reposted',
#   'bjanetrose',
#   'artist',
#   'arthur',
#   'berzinsh',
#   'iiii',
#   'http',
#   'co',
#   'vp3ikayJar'],
#  ['reposted',
#   'lordrarerock',
#   'seems',
#   'james',
#   'gang',
#   'performing',
#   'walk',
#   'away',
#   '1971',
#   'beat',
#   'club',
#   'iiii',
#   'http',
#   'co',
#   'fmz8vqfqoy'],
#  ['reposted',
#   'mothpete',
#   'ai',
#   'art',
#   'animator',
#   'mothpete',
#   'software',
#   'werbleapp',
#   'iiii',
#   'http',
#   'co',
#   'wqecujaqFr'],
#  ['reposted',
#   'infernal',
#   'art',
#   'witch',
#   'sirin',
#   'waldemar',
#   'von',
#   'kozak',
#   'twilight',
#   'time',
#   'witching',
#   'hour',
#   'praise',
#   'might',
#   'time',
#   'devil',
#   'blood',
#   'iiii',
#   'http',
#   'co',
#   'Cis7fc7rQO'],
#  ['happy', 'birthday', 'nikkisixx', 'iiii', 'http', 'co', 'wz6yklltfp'],
#  ['happy',
#   'birthday',
#   'creative',
#   'mastermind',
#   'brother',
#   'ashhudson',
#   'ashflix',
#   'n',
#   'chill',
#   'iiii',
#   'http',
#   'co',
#   'ekonrnnwdp'],
#  ['reposted',
#   'bencordova',
#   'guitar',
#   'woody',
#   'ronwood',
#   'ronniewood',
#   'face',
#   'ohlala',
#   'thefaces',
#   'ronnielane',
#   'britrock',
#   'uk',
#   'iiii',
#   'http',
#   'co',
#   'wn4mlqnsfn'],
#  ['reposted',
#   'jess',
#   'rene',
#   'art',
#   'bartheijlen',
#   'death',
#   'instaart',
#   'skull',
#   'skeleton',
#   'darkart',
#   'dark',
#   'macabre',
#   'mood',
#   'instagood',
#   'horror',
#   'gore',
#   'evil',
#   'macabreart',
#   'weekendvibes',
#   'iiii',
#   'http',
#   'co',
#   '8yvjexga1c'],
#  ['reposted', 'worldofdisnep', 'dangrlab', 'iiii', 'http', 'co', 'agvxfxvpyo'],
#  ['thank',
#   'auckland',
#   'nz',
#   'fitting',
#   'end',
#   'tour',
#   'southern',
#   'hemisphere',
#   'guy',
#   'amazing',
#   'rain',
#   'amp',
#   'one',
#   'book',
#   'rnfnr',
#   'cheer',
#   'iiii'],
#  ['help',
#   'environment',
#   'planting',
#   'tree',
#   'created',
#   'xrayted',
#   'zone',
#   'NFt',
#   'collaboration',
#   'slash',
#   'marta',
#   'zawadzka',
#   'support',
#   'onetreeplanted',
#   'limited',
#   'collection',
#   '6',
#   'NFt',
#   'drop',
#   'announced',
#   'join',
#   'XRAYtED',
#   'zone',
#   'discord',
#   'http',
#   'co',
#   'zaqp6eehbx',
#   'http',
#   'co',
#   '4b69xytzku'],
#  ['reposted',
#   'thelegendsofmusic',
#   'white',
#   'stripe',
#   'playing',
#   'hardest',
#   'button',
#   'button',
#   'live',
#   'reading',
#   'festival',
#   '2004',
#   'music',
#   'rockNroll',
#   'thewhitestripes',
#   'jackwhite',
#   'megwhite',
#   'iiii',
#   'http',
#   'co',
#   'UIscuuziko'],
#  ['reposted',
#   'paulrosolie',
#   'last',
#   'two',
#   'week',
#   'raised',
#   'enough',
#   'money',
#   'protect',
#   '1000',
#   'acre',
#   'rainforest',
#   'thank',
#   'everyone',
#   'boosted',
#   'shared',
#   'especially',
#   'thank',
#   'everyone',
#   'donated',
#   'junglekeepers',
#   'iiii',
#   'http',
#   'co',
#   'kvwkdvsbfv'],
#  ['reposted', 'bjanetrose', 'wonderwoman', 'iiii', 'http', 'co', 'powij5ohoi'],
#  ['reposted',
#   'dropkickblues',
#   'chuck',
#   'berry',
#   'legend',
#   'iiii',
#   'http',
#   'co',
#   'hlkbPkwllv'],
#  ['hell',
#   'crowd',
#   'wellington',
#   'nz',
#   'tonight',
#   'guy',
#   'kick',
#   'as',
#   'thank',
#   'like',
#   'add',
#   '4',
#   'wonderful',
#   'day',
#   'wellington',
#   'thank',
#   'super',
#   'cool',
#   'people',
#   'pleasure',
#   'interacting',
#   'genuine',
#   'hospitality',
#   'cheer',
#   'iiii']]

# %%
tweetSentences
# Out:
# ['rip tomverlaine http co w40igeqmkk',
#  'reposted vintage cheese shesjustdrawnthatway terrygilliam montypython legend 1960s 1970s vintagecheese iiii http co 2hpfzj1jVM',
#  'reposted thehorrorgallery follow u thehorrorgallery peligrosovalley iiii http co xkpm5rUwp3',
#  'reposted jess rene art witch witchcraft instaart macabre macabreart artist darkart dark instagood salem joseph tomanek philip hofmanner iiii http co wvuuumxzll',
#  'reposted bjanetrose kostle laugh dead iiii http co cgv2hmyl1i',
#  'posted photo http co Vjjloc4scg',
#  'posted photo http co 2y6cfktrvw',
#  'posted photo http co a8nKjpfqho',
#  'reposted bizarredoctor season witch sound artist minelauvart iiii http co jspww6de3k',
#  'happy birthday steveadler iiii http co q2hjtdrmsa',
#  'reposted patfromstoke1 reposted fakedreams ai iiii http co spfo4fhakc',
#  'reposted bjanetrose artist trinitycatdeline iiii http co 9lgrwvg1nj',
#  'reposted jayprehistoricpets one absolutely giant komodo dragon seems like living dinosaur run laura iiii http co qc9jsxubif',
#  'reposted thelegendsofmusic carl perkins playing honey live 1956 music rockNroll carlperkins iiii http co 3r6xlhprov',
#  'http co azjzxpfqsi iiii',
#  'reposted worldofdisnep imadeej iiii http co 5couAFjtl6',
#  'rip davidcrosby http co vblwdqdcj0',
#  'art xoticartwork iiii http co hstneis1qm',
#  'reposted thelegendsofmusic stone temple pilot playing crackerman live music rockNroll stonetemplepilots scottweiland deandeleo robertdeleo ericketz iiii http co bizzg3udV3',
#  'happy birthday micktaylor iiii http co jstmsi2t2z',
#  'available neW collection slash standard edition offer widely accessible version book featuring 364 page hardcover 240 x 340 mm 9 45 x 13 39 slashnews http co pgrlnjUeDY',
#  'reposted crave wild knock knock jukinmedia via bestialnature pay tf clock im comin collect iiii http co mg4vwhbtpt',
#  'reposted thewhiskyagogo 59 year ago whisky born happy birthday whisky go go thewhiskyagogo happybirthday thewhiskyis59 happybirthdaywhisky whiskyjanuary16th whiskyjanuary16th1964 iiii http co ibqoe31kxt',
#  'happy 8th anniversary worlovesmrslash official fan page supporting smKC thanks dedicated commitment time cheer iiii',
#  'posted photo http co 7rfq4zn1h1',
#  'reposted lordrarerock oh sings joni mitchell mesmerizes one largest gathering human history california isle wight festival 1970 iiii http co ytXBwlaujz',
#  'happy birthday zakwylde iiii http co j6XYz7itxk',
#  'repost jess rene iiii http co mzfxle6hze',
#  'happy birthday davegrohl iiii http co nyc26dNb6c',
#  'sad news rip robbieknievel http co auIWmkkNht',
#  'reposted factpilers creepy creepyashell creepyasfuck creepypopcorn popcornfaces skull iiii http co 5uyxkg9ZLr',
#  'reposted wildattractions mejdinho emerald tree boa iiii http co vlczhptdqg',
#  'reposted mrwupass repost liveguitarsolos rIp jeff beck perfect example genius thank jb http co wjqhyhSdwe',
#  'posted photo http co llsyrsevho',
#  'reposted zugart iiii http co e8jj3hufaf',
#  'reposted thelegendsofmusictv queen stone age playing sat ocean live david letterman show music rockNroll queensofthestoneage davegrohl joshhomme troyvanleeuwen deanfertita michaelshuman joecastillo iiii http co b29tajdklu',
#  'happy birthday rodstewart photo rosshalfin iiii http co 7eu0wcDAbu',
#  'reposted 52graham52 iiii http co OrO7adrnth',
#  'happy birthday davidjohansen iiii http co fyhl2Tjfnb',
#  'happy birthday jimmypage photo rosshalfin iiii http co xendyoy2wu',
#  'shop online get 30 storewide part slash winter sale slashnews http co 5dbmof8zlz',
#  'reposted guitarsdaily iiii http co 3dvgh72osm',
#  'check friend corinhardy killer series gangsoflondon amcplus nothing short bad as corinhardy amcplus gangsoflondon iiii http co b3afhcA3zk',
#  'posted photo http co w6xw8bhmk3',
#  'iiii http co 5e9bzatmyl',
#  'reposted thelegendsofmusic iggy pop playing lust life live manchester 1977 music rockNroll iggypop davidbowie iiii http co 6qwazssnj6',
#  '1928 photographer unknown iiii http co abbdk8ndye',
#  'happy 10 year anniversary fansofslashw 10 year representing sMKC thanks ongoing support time 10 cheer iiii',
#  'reposted darkmatterincorp alternate ending get shirt sticker http co qpzdtutjiq dm commission iiii http co zn7sc2b4tw',
#  'reposted mirror NUDErObOT nuderobot yassine cavalier iiii http co yuiznhigxb',
#  'reposted thelegendsofmusic pretender playing tattoo love boy live 1980 music rockNroll pretender chrissiehynde martinchambers petefarndon jameshoneymanscott iiii http co hV9gYbr80b',
#  'reposted bencordova guitar face rodstewartandthefaces paulmccartney iiii http co cpg6c2tufv',
#  'reposted toxictoons great week iiii http co ylv0l3mekb',
#  'reposted thelegendsofmusic promotional footage sid vicious performing sex pistol cover frank sinatra way music punkrock sexpistols sidvicious glenmatlock johnlydon paulcook stevejones iiii http co ytwndbxmxt',
#  'happy new year iiii http co h2bcmzkzgu',
#  'happy birthday tomhamilton iiii http co 6qyw2ffd8w',
#  'rt marta zawadzka help environment planting tree created xrayted zone NFt collaboration slas amp marta zawadz',
#  'reposted anti cgi war gargantua 1966 iiii http co iqy40nlmb5',
#  'reposted fmx motocrosss robbiemaddison iiii http co lj0ahj8u0c',
#  'posted photo http co yydeerl6tv',
#  'reposted lordrarerock WhaTEVEr GIrL put spell jimi hendrix performing purple haze atlanta pop festival 1970 iiii http co 7bt6ukau38',
#  'happy 10th anniversary slashbolivia supporting smKC massive thanks continued representation let go another 10 year cheer iiii',
#  'reposted eratk666 wonkaface darkmatterincorp iiii http co dae7n0au5p',
#  'reposted thelegendsofmusic motorhead playing damage case live 2002 music rockNroll lemmykilmister philcampbell mikkeydee iiii http co yqtufgrWot',
#  'reposted blue tshirt iiii http co qefkb3h54e',
#  'happy birthday larsulrich iiii http co 2f8rRhhooe',
#  'reposted creep sock twilight zone night meek 1959 another christmas speical recommendation iiii http co rLmVtYg8k9',
#  'merry christmas reposted patfromstoke1 reposted motorhead fanlove01 mot rhead lemmy iiii http co rNsbhetuaf',
#  'reposted thelegendsofmusic kiss playing god thunder live tokyo 1977 music rockNroll kiss genesimmons paulstanley petercriss iiii http co wdhkQwq391',
#  'check fantastic photo expose eddievanhalen iconic rock photographer neilzlowzower best photo history evh unbelievable quality iiii http co ye884KCvzt',
#  'reposted rorygallagherofficial rory playing learnt lesson german tv show beat club day 1971 iiii http co mwfyohhsbx',
#  'reposted lordrarerock rEMEMBEr someone rEAllY love highwayman play live forever live studio 1995 highwayman featured country legend johnny cash waylon jennings kris kristofferson willie nelson iiii http co ax4dh8GZlG',
#  'reposted thehorrorgallery iiii http co 1CHruuvldp',
#  'posted photo http co e6ki6itil6',
#  'posted photo http co cyoz0zypmu',
#  'reposted 52graham52 iiii http co yyckcs4zob',
#  'today slash2world celebrates 10th anniversary official fan page smkc thank support cheer iiii',
#  'reposted dropkickblues james brown time live david letterman 1982 performance called best live performance television history iiii http co cbem70zfrs',
#  'happy birthday keithrichards iiii http co qmh0qxgyg1',
#  'reposted lisarosa statue liberty construction 1885 iiii http co 0DtNagzy3m',
#  'reposted bizarredoctor muppet mania 10 bizarre wild snap artist sentientmuppetfactory beth frey iiii http co 6el3kdtrnj',
#  'reposted thelegendsofmusic aerosmith playing livin edge live 1994 music rockNroll aerosmith bradwhitford joeperry tomhamilton joeykramer steventyler iiii http co gtlrbeYGlr',
#  'happy birthday billyfgibbons iiii http co shszc51gh6',
#  'reposted eratk666 creaturete saucy lagoon mark alfreys laguna marKalFrEY mark alfrey art iiii http co 9iujj4sG2f',
#  'reposted bjanetrose artist arthur berzinsh iiii http co vp3ikayJar',
#  'reposted lordrarerock seems james gang performing walk away 1971 beat club iiii http co fmz8vqfqoy',
#  'reposted mothpete ai art animator mothpete software werbleapp iiii http co wqecujaqFr',
#  'reposted infernal art witch sirin waldemar von kozak twilight time witching hour praise might time devil blood iiii http co Cis7fc7rQO',
#  'happy birthday nikkisixx iiii http co wz6yklltfp',
#  'happy birthday creative mastermind brother ashhudson ashflix n chill iiii http co ekonrnnwdp',
#  'reposted bencordova guitar woody ronwood ronniewood face ohlala thefaces ronnielane britrock uk iiii http co wn4mlqnsfn',
#  'reposted jess rene art bartheijlen death instaart skull skeleton darkart dark macabre mood instagood horror gore evil macabreart weekendvibes iiii http co 8yvjexga1c',
#  'reposted worldofdisnep dangrlab iiii http co agvxfxvpyo',
#  'thank auckland nz fitting end tour southern hemisphere guy amazing rain amp one book rnfnr cheer iiii',
#  'help environment planting tree created xrayted zone NFt collaboration slash marta zawadzka support onetreeplanted limited collection 6 NFt drop announced join XRAYtED zone discord http co zaqp6eehbx http co 4b69xytzku',
#  'reposted thelegendsofmusic white stripe playing hardest button button live reading festival 2004 music rockNroll thewhitestripes jackwhite megwhite iiii http co UIscuuziko',
#  'reposted paulrosolie last two week raised enough money protect 1000 acre rainforest thank everyone boosted shared especially thank everyone donated junglekeepers iiii http co kvwkdvsbfv',
#  'reposted bjanetrose wonderwoman iiii http co powij5ohoi',
#  'reposted dropkickblues chuck berry legend iiii http co hlkbPkwllv',
#  'hell crowd wellington nz tonight guy kick as thank like add 4 wonderful day wellington thank super cool people pleasure interacting genuine hospitality cheer iiii']
