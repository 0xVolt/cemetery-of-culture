# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Function to implement the gradient descent algorithm

# %%
def gradient_descent(start, gradient, learning_rate, max_iterations, tolerance=0.01):
    # To track the history of the algorithm
    trace = [start]
    optimiserValue = start
    
    # To count the number of iterations
    iterations = 0

    for _ in range(max_iterations):
        diff = learning_rate * gradient(optimiserValue)
        
        if np.abs(diff) < tolerance:
            break
        
        optimiserValue = optimiserValue - diff
        
        # Track the value and append it to the list
        trace.append(optimiserValue)
        
        iterations += 1
        
    return trace, optimiserValue, iterations

# %% [markdown]
# ### Defining our test function and it's gradient

# %%
def function(x):
    return x ** 2 - 4 * x + 1

def gradient(x):
    return 2 * x - 4

# %% [markdown]
# ### Calling the gradient descent function

# %%
history, result, iterations = gradient_descent(start=10, gradient=gradient, learning_rate=0.01, max_iterations=100)

# %% [markdown]
# ### Tracing the change in the gradient value over iterations.

# %%
print(f'Tracing the gradients:\n{history}\n\nFinal Result of the gradient descent algorithm: {result}')
# Out:
# Tracing the gradients:
# [10, 9.84, 9.6832, 9.529536, 9.37894528, 9.2313663744, 9.086739046912001, 8.945004265973761, 8.806104180654286, 8.6699820970412, 8.536582455100374, 8.405850805998368, 8.2777337898784, 8.152179114080832, 8.029135531799216, 7.908552821163232, 7.790381764739967, 7.674574129445168, 7.561082646856264, 7.449860993919139, 7.3408637740407565, 7.234046498559941, 7.129365568588742, 7.026778257216967, 6.926242692072628, 6.827717838231175, 6.7311634814665515, 6.636540211837221, 6.5438094076004765, 6.452933219448467, 6.363874555059498, 6.276597063958308, 6.1910651226791416, 6.107243820225559, 6.025098943821048, 5.944596964944627, 5.865705025645735, 5.78839092513282, 5.712623106630163, 5.63837064449756, 5.565603231607609, 5.494291166975457, 5.424405343635948, 5.355917236763229, 5.288798892027964, 5.223022914187405, 5.158562455903657, 5.0953912067855835, 5.033483382649872, 4.9728137149968745, 4.913357440696937, 4.855090291882998, 4.797988486045338, 4.742028716324431, 4.687188141997942, 4.633444379157983, 4.5807754915748236, 4.5291599817433275, 4.478576782108461, 4.429005246466292, 4.380425141536966, 4.332816638706227, 4.2861603059321025, 4.240437099813461, 4.195628357817191, 4.151715790660847, 4.10868147484763, 4.066507845350678, 4.025177688443664, 3.984674134674791, 3.944980651981295, 3.906081038941669, 3.8679594181628354, 3.8306002297995785, 3.793988225203587, 3.7581084606995154, 3.722946291485525, 3.6884873656558144, 3.654717618342698, 3.621623265975844, 3.5891908006563273, 3.5574069846432006, 3.5262588449503367, 3.49573366805133, 3.465818994690303, 3.436502614796497, 3.4077725625005675, 3.379617111250556, 3.3520247690255447, 3.324984273645034, 3.2984845881721334, 3.2725148964086905, 3.2470645984805167, 3.2221233065109063, 3.1976808403806882, 3.1737272235730742, 3.1502526791016128, 3.1272476255195807, 3.104702673009189, 3.082608619549005, 3.060956447158025]
#
# Final Result of the gradient descent algorithm: 3.060956447158025

# %% [markdown]
# #### Plotting the change in gradient

# %%
plt.title('Change in Gradient Value')

plt.xlabel('Iteration')
plt.ylabel('Gradient Value')

plt.grid()

plt.plot(history)
